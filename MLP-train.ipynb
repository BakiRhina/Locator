# %%
# !pip install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)

# %%
import torch
import math
import numpy as np
from math import sqrt
from torch import nn
from torch.nn import init
from torch.nn import functional as F
from torchsummary import summary
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm, trange

# %%
# Here's MLP scoring test
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.leakyrelu = nn.LeakyReLU(0.2)
        # self.dropout = nn.Dropout(p=0.2)
        self.fc2 = nn.Linear(hidden_dim, output_dim)
    
    def forward(self, x1, x2, max_len):
        cosine_score = F.cosine_similarity(x1, x2)
        tensor_similarity = torch.Tensor([[cosine_score]])
        tensor_max_len = torch.Tensor([[max_len]])

        tensor_similarity.requires_grad_(True)
        tensor_max_len.requires_grad_(True)

        x = torch.cat((x1, x2, tensor_similarity, tensor_max_len), dim=1)
        x = self.fc1(x)
        x = self.leakyrelu(x)
        x = self.fc2(x)

        x = torch.abs(x)

        return x

# # 创建并使用MLP模型
# input_dim = 50*2  # 连接后的向量维度
# hidden_dim = 128
# output_dim = 1  # 输出一个分数
# mlp = MLP(input_dim, hidden_dim, output_dim)

# # 生成示例输入向量
# vector1 = torch.randn(1, 50)  # 第一个向量
# vector2 = torch.randn(1, 50)  # 第二个向量

# # 将输入向量传递给MLP模型
# # score = mlp(vector1, vector2)

# # print('This is the score', score)  # 输出分数张量

# %% [markdown]
# ### Training MLP vs cosine similarity

# %%
# Test cosine similarity with MLP

# 创建并使用MLP模型
input_dim = 50*2  # 连接后的向量维度
hidden_dim = 128
output_dim = 1  # 输出一个分数
mlp = MLP(input_dim, hidden_dim, output_dim)

# build 3 testing tensor
tensor1 = torch.randn(1, 50)
tensor2 = tensor1.clone()  # 通过克隆方式创建一个与tensor1相同的张量
tensor3 = torch.randn(1, 50) # 创建一个不相似的张量

# 将两个向量连接成一个输入向量
input_vector_1 = torch.cat((tensor1, tensor2), dim=1)  # 2 similar vectors
input_vector_2 = torch.cat((tensor1, tensor3), dim=1)  # 2 non-similar vectors

print(input_vector_1)
print(input_vector_2)

# 将输入向量传递给MLP模型
score_1 = mlp(tensor1, tensor2)
score_2 = mlp(tensor1, tensor3)

print('This is the score-1', score_1)  # 输出分数张量
print('This is the score-2', score_2)  # 输出分数张量


similarity_score_1 = F.cosine_similarity(tensor1, tensor2)
similarity_score_2 = F.cosine_similarity(tensor1, tensor3)

print('This is the cos score-1', similarity_score_1)  # 输出分数张量
print('This is the cos score-2', similarity_score_2)  # 输出分数张量
# Out:
# tensor([[ 0.9346, -0.0190, -0.0442, -1.1277, -2.2433,  1.0628,  0.2738, -0.7498,
#           1.4525,  0.5115,  1.4996,  0.2842,  0.1637,  1.6438,  0.7192,  1.7105,
#           0.7663,  0.1757, -0.3213, -0.1413,  0.4713, -0.1653, -1.0831,  1.7135,
#          -0.0699,  0.8162,  0.8200,  0.9509,  1.7064, -1.0233,  1.0895,  0.7483,
#          -0.1954, -1.1060, -1.2792, -2.2550, -0.4848,  0.8326,  1.9951, -0.8836,
#           0.1315, -0.5436, -0.3903, -1.9608, -0.2627,  0.2624,  1.4792,  0.2979,
#           1.4561, -0.0064,  0.9346, -0.0190, -0.0442, -1.1277, -2.2433,  1.0628,
#           0.2738, -0.7498,  1.4525,  0.5115,  1.4996,  0.2842,  0.1637,  1.6438,
#           0.7192,  1.7105,  0.7663,  0.1757, -0.3213, -0.1413,  0.4713, -0.1653,
#          -1.0831,  1.7135, -0.0699,  0.8162,  0.8200,  0.9509,  1.7064, -1.0233,
#           1.0895,  0.7483, -0.1954, -1.1060, -1.2792, -2.2550, -0.4848,  0.8326,
#           1.9951, -0.8836,  0.1315, -0.5436, -0.3903, -1.9608, -0.2627,  0.2624,
#           1.4792,  0.2979,  1.4561, -0.0064]])
# tensor([[ 0.9346, -0.0190, -0.0442, -1.1277, -2.2433,  1.0628,  0.2738, -0.7498,
#           1.4525,  0.5115,  1.4996,  0.2842,  0.1637,  1.6438,  0.7192,  1.7105,
#           0.7663,  0.1757, -0.3213, -0.1413,  0.4713, -0.1653, -1.0831,  1.7135,
#          -0.0699,  0.8162,  0.8200,  0.9509,  1.7064, -1.0233,  1.0895,  0.7483,
#          -0.1954, -1.1060, -1.2792, -2.2550, -0.4848,  0.8326,  1.9951, -0.8836,
#           0.1315, -0.5436, -0.3903, -1.9608, -0.2627,  0.2624,  1.4792,  0.2979,
#           1.4561, -0.0064, -0.0776,  1.0222,  0.6082, -0.4485, -0.6015,  1.0541,
#          -0.0327, -0.5315,  3.0040,  0.7317, -0.1300,  0.5422,  0.2423,  0.1113,
#          -1.0905,  0.4238,  0.3906,  0.7730, -0.0802,  0.9241,  1.8901, -1.6750,
#          -0.4235,  0.1691,  0.2929, -0.2947, -0.6310,  0.5512, -1.3907,  0.0234,
#           0.4936,  0.1052, -0.8305,  1.9926, -0.7071, -0.9574, -0.2837, -0.2175,
#           0.0558,  0.9062,  0.7939,  0.4616, -0.1897, -0.5888,  1.8089, -0.1499,
#           0.3818,  1.2158, -1.8495,  0.1109]])
# This is the score-1 tensor([[0.1281]], grad_fn=<AddmmBackward0>)
# This is the score-2 tensor([[0.1056]], grad_fn=<AddmmBackward0>)
# This is the cos score-1 tensor([1.])
# This is the cos score-2 tensor([0.1526])

# %% [markdown]
# ### Training MLP test

# %%
# Build a Locater with CNN+MLP
''' CNN accept transcript or query and convert it into average embedding, 
    MLP accept query embedding & transcript embedding and convert it into a 2-D vector as <start, end> of relevant spans '''

class testCNNModel(nn.Module):
    def __init__(self):
        super(testCNNModel, self).__init__()
        
        self.conv1d = nn.Conv1d(in_channels=512, out_channels=256, kernel_size=1)
        # self.relu = nn.ReLU()
        # self.drop = nn.Dropout(0.2)
        self.maxpool = nn.MaxPool1d(kernel_size=1)
        self.linear = nn.Linear(196608, 50)   # fully-connected layer
    
    def forward(self, x):
        x = x.requires_grad_(True)
        x = self.conv1d(x)
        # x = self.drop(x)
        x = self.maxpool(x)
        x = torch.flatten(x, start_dim=1)  # 将张量展平
        x = self.linear(x)
        return x

class Locater(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        self.CNN = testCNNModel()
        self.MLP = MLP(input_dim, hidden_dim, output_dim)

    def forward(self, transcript_emb, query_emb, max_len):
        transcript_cnn_out = self.CNN(transcript_emb)
        query_cnn_out = self.CNN(query_emb)

        spans_id = self.MLP(transcript_cnn_out, query_cnn_out, max_len)

        return spans_id

# %% [markdown]
# ### Training test

# %%
# Test data
transcript_emb = torch.randn(1, 512, 768)  # tensor for transcript
query_emb_1 = torch.randn(1, 512, 768)  # tensor for query
query_emb_2 = torch.randn(1, 512, 768)
query_emb_3 = torch.randn(1, 512, 768)
query_emb_4 = torch.randn(1, 512, 768)

transcript_emb.requires_grad_(True)
query_emb_1.requires_grad_(True)
query_emb_2.requires_grad_(True)
query_emb_3.requires_grad_(True)
query_emb_4.requires_grad_(True)

# Label
label_1 = torch.Tensor([24, 30])
label_2 = torch.Tensor([0, 10])
label_3 = torch.Tensor([24, 26])
label_4 = torch.Tensor([25, 32])

label_1.requires_grad_(True)
label_2.requires_grad_(True)
label_3.requires_grad_(True)
label_4.requires_grad_(True)

query_set = [query_emb_1, query_emb_2, query_emb_3, query_emb_4]
start_end_label = [label_1, label_2, label_3, label_4] #label

# Instantiate Locater
input_dim = 50*2  # Dimension after connected
hidden_dim = 128
output_dim = 2  # output <start, end> spans
locater = Locater(input_dim, hidden_dim, output_dim)


# Loss function
# criterion = nn.CrossEntropyLoss()  # can't work
criterion = nn.MSELoss()  

# Optimizer
from torch import optim
optimizer = optim.Adam(mlp.parameters(), lr=0.001)

num_epochs = 10

for epoch in range(num_epochs):
  running_loss = 0.0
  for i, (inputs_query, label) in enumerate(zip(query_set, start_end_label)):
    print('i=',i)
    print('inputs=',inputs_query)
    # 前向传播
    spans = locater(transcript_emb, inputs_query)
    loss = criterion(spans, label)  # 计算loss误差

    print('predicted spans: ', spans)

    # 反向传播和优化
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    running_loss += loss.item()

    # 打印每个epoch的平均损失
  epoch_loss = running_loss / len(query_set)
  print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss}")
  print('------------------------------------------------------')
# Out:
# i= 0
# inputs= tensor([[[-0.2619, -0.6147,  0.7968,  ..., -0.2643,  1.1212,  0.7796],
#          [-0.1804, -0.4150, -0.6541,  ...,  0.7962,  1.4538, -1.2213],
#          [-1.0690, -0.1759, -0.7373,  ..., -0.1449,  1.4295, -1.4209],
#          ...,
#          [-0.3537, -0.8999, -1.2690,  ...,  0.8678,  1.3526,  1.7176],
#          [ 1.4875,  0.1943, -2.9266,  ...,  1.3069, -0.1743,  0.8847],
#          [ 0.1588,  0.0406,  1.1313,  ..., -0.2899, -0.9426,  0.9801]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 1
# inputs= tensor([[[ 0.4778,  1.3883, -0.8741,  ...,  1.4224,  2.2957, -0.3944],
#          [ 2.6525, -0.4972,  1.7572,  ...,  0.0954, -0.4087, -0.5127],
#          [-0.6099,  1.3736, -0.4484,  ...,  1.0382, -0.3736, -1.4498],
#          ...,
#          [ 0.2059,  0.4491, -1.7673,  ..., -0.4939,  0.3272, -0.9960],
#          [ 0.8828,  0.0485, -1.8293,  ..., -0.2453,  0.9305, -1.6672],
#          [-0.9344,  0.7967, -0.4213,  ...,  0.8275, -0.8511, -1.0107]]],
#        requires_grad=True)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([2])) that is different to the input size (torch.Size([1, 2])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 2
# inputs= tensor([[[-0.9681,  0.2716,  1.4775,  ...,  1.4349, -0.4828, -2.3926],
#          [-1.9622,  1.5685, -0.3171,  ..., -1.3052,  0.7432,  0.2840],
#          [-0.3171, -1.1408,  0.8333,  ..., -0.0348,  0.1850,  0.9617],
#          ...,
#          [-1.1376, -0.0100,  0.7508,  ...,  0.2652,  0.7560, -0.2433],
#          [-2.0999,  0.9153, -0.3850,  ...,  0.4209,  0.6160,  0.0331],
#          [ 0.0519, -1.1740,  2.9918,  ...,  0.3874, -0.9176,  1.0621]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 3
# inputs= tensor([[[ 1.4751, -2.2790, -0.5338,  ..., -0.2522, -0.2616, -1.3452],
#          [ 0.3894,  1.0400, -0.5621,  ..., -0.7888,  0.2940, -1.3033],
#          [-1.3584, -0.2238, -2.6254,  ..., -0.6882, -0.4461,  0.0454],
#          ...,
#          [-0.2897,  0.7729, -0.4392,  ...,  0.5651, -1.3621, -0.3709],
#          [-1.3717, -1.3365, -0.6513,  ..., -0.4769,  0.2960,  0.5230],
#          [ 0.3976, -0.3644,  1.9948,  ...,  1.6095, -0.6920,  0.7229]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# Epoch [1/10], Loss: 559.625
# ------------------------------------------------------
# i= 0
# inputs= tensor([[[-0.2619, -0.6147,  0.7968,  ..., -0.2643,  1.1212,  0.7796],
#          [-0.1804, -0.4150, -0.6541,  ...,  0.7962,  1.4538, -1.2213],
#          [-1.0690, -0.1759, -0.7373,  ..., -0.1449,  1.4295, -1.4209],
#          ...,
#          [-0.3537, -0.8999, -1.2690,  ...,  0.8678,  1.3526,  1.7176],
#          [ 1.4875,  0.1943, -2.9266,  ...,  1.3069, -0.1743,  0.8847],
#          [ 0.1588,  0.0406,  1.1313,  ..., -0.2899, -0.9426,  0.9801]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 1
# inputs= tensor([[[ 0.4778,  1.3883, -0.8741,  ...,  1.4224,  2.2957, -0.3944],
#          [ 2.6525, -0.4972,  1.7572,  ...,  0.0954, -0.4087, -0.5127],
#          [-0.6099,  1.3736, -0.4484,  ...,  1.0382, -0.3736, -1.4498],
#          ...,
#          [ 0.2059,  0.4491, -1.7673,  ..., -0.4939,  0.3272, -0.9960],
#          [ 0.8828,  0.0485, -1.8293,  ..., -0.2453,  0.9305, -1.6672],
#          [-0.9344,  0.7967, -0.4213,  ...,  0.8275, -0.8511, -1.0107]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 2
# inputs= tensor([[[-0.9681,  0.2716,  1.4775,  ...,  1.4349, -0.4828, -2.3926],
#          [-1.9622,  1.5685, -0.3171,  ..., -1.3052,  0.7432,  0.2840],
#          [-0.3171, -1.1408,  0.8333,  ..., -0.0348,  0.1850,  0.9617],
#          ...,
#          [-1.1376, -0.0100,  0.7508,  ...,  0.2652,  0.7560, -0.2433],
#          [-2.0999,  0.9153, -0.3850,  ...,  0.4209,  0.6160,  0.0331],
#          [ 0.0519, -1.1740,  2.9918,  ...,  0.3874, -0.9176,  1.0621]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 3
# inputs= tensor([[[ 1.4751, -2.2790, -0.5338,  ..., -0.2522, -0.2616, -1.3452],
#          [ 0.3894,  1.0400, -0.5621,  ..., -0.7888,  0.2940, -1.3033],
#          [-1.3584, -0.2238, -2.6254,  ..., -0.6882, -0.4461,  0.0454],
#          ...,
#          [-0.2897,  0.7729, -0.4392,  ...,  0.5651, -1.3621, -0.3709],
#          [-1.3717, -1.3365, -0.6513,  ..., -0.4769,  0.2960,  0.5230],
#          [ 0.3976, -0.3644,  1.9948,  ...,  1.6095, -0.6920,  0.7229]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# Epoch [2/10], Loss: 559.625
# ------------------------------------------------------
# i= 0
# inputs= tensor([[[-0.2619, -0.6147,  0.7968,  ..., -0.2643,  1.1212,  0.7796],
#          [-0.1804, -0.4150, -0.6541,  ...,  0.7962,  1.4538, -1.2213],
#          [-1.0690, -0.1759, -0.7373,  ..., -0.1449,  1.4295, -1.4209],
#          ...,
#          [-0.3537, -0.8999, -1.2690,  ...,  0.8678,  1.3526,  1.7176],
#          [ 1.4875,  0.1943, -2.9266,  ...,  1.3069, -0.1743,  0.8847],
#          [ 0.1588,  0.0406,  1.1313,  ..., -0.2899, -0.9426,  0.9801]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 1
# inputs= tensor([[[ 0.4778,  1.3883, -0.8741,  ...,  1.4224,  2.2957, -0.3944],
#          [ 2.6525, -0.4972,  1.7572,  ...,  0.0954, -0.4087, -0.5127],
#          [-0.6099,  1.3736, -0.4484,  ...,  1.0382, -0.3736, -1.4498],
#          ...,
#          [ 0.2059,  0.4491, -1.7673,  ..., -0.4939,  0.3272, -0.9960],
#          [ 0.8828,  0.0485, -1.8293,  ..., -0.2453,  0.9305, -1.6672],
#          [-0.9344,  0.7967, -0.4213,  ...,  0.8275, -0.8511, -1.0107]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 2
# inputs= tensor([[[-0.9681,  0.2716,  1.4775,  ...,  1.4349, -0.4828, -2.3926],
#          [-1.9622,  1.5685, -0.3171,  ..., -1.3052,  0.7432,  0.2840],
#          [-0.3171, -1.1408,  0.8333,  ..., -0.0348,  0.1850,  0.9617],
#          ...,
#          [-1.1376, -0.0100,  0.7508,  ...,  0.2652,  0.7560, -0.2433],
#          [-2.0999,  0.9153, -0.3850,  ...,  0.4209,  0.6160,  0.0331],
#          [ 0.0519, -1.1740,  2.9918,  ...,  0.3874, -0.9176,  1.0621]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 3
# inputs= tensor([[[ 1.4751, -2.2790, -0.5338,  ..., -0.2522, -0.2616, -1.3452],
#          [ 0.3894,  1.0400, -0.5621,  ..., -0.7888,  0.2940, -1.3033],
#          [-1.3584, -0.2238, -2.6254,  ..., -0.6882, -0.4461,  0.0454],
#          ...,
#          [-0.2897,  0.7729, -0.4392,  ...,  0.5651, -1.3621, -0.3709],
#          [-1.3717, -1.3365, -0.6513,  ..., -0.4769,  0.2960,  0.5230],
#          [ 0.3976, -0.3644,  1.9948,  ...,  1.6095, -0.6920,  0.7229]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# Epoch [3/10], Loss: 559.625
# ------------------------------------------------------
# i= 0
# inputs= tensor([[[-0.2619, -0.6147,  0.7968,  ..., -0.2643,  1.1212,  0.7796],
#          [-0.1804, -0.4150, -0.6541,  ...,  0.7962,  1.4538, -1.2213],
#          [-1.0690, -0.1759, -0.7373,  ..., -0.1449,  1.4295, -1.4209],
#          ...,
#          [-0.3537, -0.8999, -1.2690,  ...,  0.8678,  1.3526,  1.7176],
#          [ 1.4875,  0.1943, -2.9266,  ...,  1.3069, -0.1743,  0.8847],
#          [ 0.1588,  0.0406,  1.1313,  ..., -0.2899, -0.9426,  0.9801]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 1
# inputs= tensor([[[ 0.4778,  1.3883, -0.8741,  ...,  1.4224,  2.2957, -0.3944],
#          [ 2.6525, -0.4972,  1.7572,  ...,  0.0954, -0.4087, -0.5127],
#          [-0.6099,  1.3736, -0.4484,  ...,  1.0382, -0.3736, -1.4498],
#          ...,
#          [ 0.2059,  0.4491, -1.7673,  ..., -0.4939,  0.3272, -0.9960],
#          [ 0.8828,  0.0485, -1.8293,  ..., -0.2453,  0.9305, -1.6672],
#          [-0.9344,  0.7967, -0.4213,  ...,  0.8275, -0.8511, -1.0107]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 2
# inputs= tensor([[[-0.9681,  0.2716,  1.4775,  ...,  1.4349, -0.4828, -2.3926],
#          [-1.9622,  1.5685, -0.3171,  ..., -1.3052,  0.7432,  0.2840],
#          [-0.3171, -1.1408,  0.8333,  ..., -0.0348,  0.1850,  0.9617],
#          ...,
#          [-1.1376, -0.0100,  0.7508,  ...,  0.2652,  0.7560, -0.2433],
#          [-2.0999,  0.9153, -0.3850,  ...,  0.4209,  0.6160,  0.0331],
#          [ 0.0519, -1.1740,  2.9918,  ...,  0.3874, -0.9176,  1.0621]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 3
# inputs= tensor([[[ 1.4751, -2.2790, -0.5338,  ..., -0.2522, -0.2616, -1.3452],
#          [ 0.3894,  1.0400, -0.5621,  ..., -0.7888,  0.2940, -1.3033],
#          [-1.3584, -0.2238, -2.6254,  ..., -0.6882, -0.4461,  0.0454],
#          ...,
#          [-0.2897,  0.7729, -0.4392,  ...,  0.5651, -1.3621, -0.3709],
#          [-1.3717, -1.3365, -0.6513,  ..., -0.4769,  0.2960,  0.5230],
#          [ 0.3976, -0.3644,  1.9948,  ...,  1.6095, -0.6920,  0.7229]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# Epoch [4/10], Loss: 559.625
# ------------------------------------------------------
# i= 0
# inputs= tensor([[[-0.2619, -0.6147,  0.7968,  ..., -0.2643,  1.1212,  0.7796],
#          [-0.1804, -0.4150, -0.6541,  ...,  0.7962,  1.4538, -1.2213],
#          [-1.0690, -0.1759, -0.7373,  ..., -0.1449,  1.4295, -1.4209],
#          ...,
#          [-0.3537, -0.8999, -1.2690,  ...,  0.8678,  1.3526,  1.7176],
#          [ 1.4875,  0.1943, -2.9266,  ...,  1.3069, -0.1743,  0.8847],
#          [ 0.1588,  0.0406,  1.1313,  ..., -0.2899, -0.9426,  0.9801]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 1
# inputs= tensor([[[ 0.4778,  1.3883, -0.8741,  ...,  1.4224,  2.2957, -0.3944],
#          [ 2.6525, -0.4972,  1.7572,  ...,  0.0954, -0.4087, -0.5127],
#          [-0.6099,  1.3736, -0.4484,  ...,  1.0382, -0.3736, -1.4498],
#          ...,
#          [ 0.2059,  0.4491, -1.7673,  ..., -0.4939,  0.3272, -0.9960],
#          [ 0.8828,  0.0485, -1.8293,  ..., -0.2453,  0.9305, -1.6672],
#          [-0.9344,  0.7967, -0.4213,  ...,  0.8275, -0.8511, -1.0107]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 2
# inputs= tensor([[[-0.9681,  0.2716,  1.4775,  ...,  1.4349, -0.4828, -2.3926],
#          [-1.9622,  1.5685, -0.3171,  ..., -1.3052,  0.7432,  0.2840],
#          [-0.3171, -1.1408,  0.8333,  ..., -0.0348,  0.1850,  0.9617],
#          ...,
#          [-1.1376, -0.0100,  0.7508,  ...,  0.2652,  0.7560, -0.2433],
#          [-2.0999,  0.9153, -0.3850,  ...,  0.4209,  0.6160,  0.0331],
#          [ 0.0519, -1.1740,  2.9918,  ...,  0.3874, -0.9176,  1.0621]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 3
# inputs= tensor([[[ 1.4751, -2.2790, -0.5338,  ..., -0.2522, -0.2616, -1.3452],
#          [ 0.3894,  1.0400, -0.5621,  ..., -0.7888,  0.2940, -1.3033],
#          [-1.3584, -0.2238, -2.6254,  ..., -0.6882, -0.4461,  0.0454],
#          ...,
#          [-0.2897,  0.7729, -0.4392,  ...,  0.5651, -1.3621, -0.3709],
#          [-1.3717, -1.3365, -0.6513,  ..., -0.4769,  0.2960,  0.5230],
#          [ 0.3976, -0.3644,  1.9948,  ...,  1.6095, -0.6920,  0.7229]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# Epoch [5/10], Loss: 559.625
# ------------------------------------------------------
# i= 0
# inputs= tensor([[[-0.2619, -0.6147,  0.7968,  ..., -0.2643,  1.1212,  0.7796],
#          [-0.1804, -0.4150, -0.6541,  ...,  0.7962,  1.4538, -1.2213],
#          [-1.0690, -0.1759, -0.7373,  ..., -0.1449,  1.4295, -1.4209],
#          ...,
#          [-0.3537, -0.8999, -1.2690,  ...,  0.8678,  1.3526,  1.7176],
#          [ 1.4875,  0.1943, -2.9266,  ...,  1.3069, -0.1743,  0.8847],
#          [ 0.1588,  0.0406,  1.1313,  ..., -0.2899, -0.9426,  0.9801]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 1
# inputs= tensor([[[ 0.4778,  1.3883, -0.8741,  ...,  1.4224,  2.2957, -0.3944],
#          [ 2.6525, -0.4972,  1.7572,  ...,  0.0954, -0.4087, -0.5127],
#          [-0.6099,  1.3736, -0.4484,  ...,  1.0382, -0.3736, -1.4498],
#          ...,
#          [ 0.2059,  0.4491, -1.7673,  ..., -0.4939,  0.3272, -0.9960],
#          [ 0.8828,  0.0485, -1.8293,  ..., -0.2453,  0.9305, -1.6672],
#          [-0.9344,  0.7967, -0.4213,  ...,  0.8275, -0.8511, -1.0107]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 2
# inputs= tensor([[[-0.9681,  0.2716,  1.4775,  ...,  1.4349, -0.4828, -2.3926],
#          [-1.9622,  1.5685, -0.3171,  ..., -1.3052,  0.7432,  0.2840],
#          [-0.3171, -1.1408,  0.8333,  ..., -0.0348,  0.1850,  0.9617],
#          ...,
#          [-1.1376, -0.0100,  0.7508,  ...,  0.2652,  0.7560, -0.2433],
#          [-2.0999,  0.9153, -0.3850,  ...,  0.4209,  0.6160,  0.0331],
#          [ 0.0519, -1.1740,  2.9918,  ...,  0.3874, -0.9176,  1.0621]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 3
# inputs= tensor([[[ 1.4751, -2.2790, -0.5338,  ..., -0.2522, -0.2616, -1.3452],
#          [ 0.3894,  1.0400, -0.5621,  ..., -0.7888,  0.2940, -1.3033],
#          [-1.3584, -0.2238, -2.6254,  ..., -0.6882, -0.4461,  0.0454],
#          ...,
#          [-0.2897,  0.7729, -0.4392,  ...,  0.5651, -1.3621, -0.3709],
#          [-1.3717, -1.3365, -0.6513,  ..., -0.4769,  0.2960,  0.5230],
#          [ 0.3976, -0.3644,  1.9948,  ...,  1.6095, -0.6920,  0.7229]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# Epoch [6/10], Loss: 559.625
# ------------------------------------------------------
# i= 0
# inputs= tensor([[[-0.2619, -0.6147,  0.7968,  ..., -0.2643,  1.1212,  0.7796],
#          [-0.1804, -0.4150, -0.6541,  ...,  0.7962,  1.4538, -1.2213],
#          [-1.0690, -0.1759, -0.7373,  ..., -0.1449,  1.4295, -1.4209],
#          ...,
#          [-0.3537, -0.8999, -1.2690,  ...,  0.8678,  1.3526,  1.7176],
#          [ 1.4875,  0.1943, -2.9266,  ...,  1.3069, -0.1743,  0.8847],
#          [ 0.1588,  0.0406,  1.1313,  ..., -0.2899, -0.9426,  0.9801]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 1
# inputs= tensor([[[ 0.4778,  1.3883, -0.8741,  ...,  1.4224,  2.2957, -0.3944],
#          [ 2.6525, -0.4972,  1.7572,  ...,  0.0954, -0.4087, -0.5127],
#          [-0.6099,  1.3736, -0.4484,  ...,  1.0382, -0.3736, -1.4498],
#          ...,
#          [ 0.2059,  0.4491, -1.7673,  ..., -0.4939,  0.3272, -0.9960],
#          [ 0.8828,  0.0485, -1.8293,  ..., -0.2453,  0.9305, -1.6672],
#          [-0.9344,  0.7967, -0.4213,  ...,  0.8275, -0.8511, -1.0107]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 2
# inputs= tensor([[[-0.9681,  0.2716,  1.4775,  ...,  1.4349, -0.4828, -2.3926],
#          [-1.9622,  1.5685, -0.3171,  ..., -1.3052,  0.7432,  0.2840],
#          [-0.3171, -1.1408,  0.8333,  ..., -0.0348,  0.1850,  0.9617],
#          ...,
#          [-1.1376, -0.0100,  0.7508,  ...,  0.2652,  0.7560, -0.2433],
#          [-2.0999,  0.9153, -0.3850,  ...,  0.4209,  0.6160,  0.0331],
#          [ 0.0519, -1.1740,  2.9918,  ...,  0.3874, -0.9176,  1.0621]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 3
# inputs= tensor([[[ 1.4751, -2.2790, -0.5338,  ..., -0.2522, -0.2616, -1.3452],
#          [ 0.3894,  1.0400, -0.5621,  ..., -0.7888,  0.2940, -1.3033],
#          [-1.3584, -0.2238, -2.6254,  ..., -0.6882, -0.4461,  0.0454],
#          ...,
#          [-0.2897,  0.7729, -0.4392,  ...,  0.5651, -1.3621, -0.3709],
#          [-1.3717, -1.3365, -0.6513,  ..., -0.4769,  0.2960,  0.5230],
#          [ 0.3976, -0.3644,  1.9948,  ...,  1.6095, -0.6920,  0.7229]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# Epoch [7/10], Loss: 559.625
# ------------------------------------------------------
# i= 0
# inputs= tensor([[[-0.2619, -0.6147,  0.7968,  ..., -0.2643,  1.1212,  0.7796],
#          [-0.1804, -0.4150, -0.6541,  ...,  0.7962,  1.4538, -1.2213],
#          [-1.0690, -0.1759, -0.7373,  ..., -0.1449,  1.4295, -1.4209],
#          ...,
#          [-0.3537, -0.8999, -1.2690,  ...,  0.8678,  1.3526,  1.7176],
#          [ 1.4875,  0.1943, -2.9266,  ...,  1.3069, -0.1743,  0.8847],
#          [ 0.1588,  0.0406,  1.1313,  ..., -0.2899, -0.9426,  0.9801]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 1
# inputs= tensor([[[ 0.4778,  1.3883, -0.8741,  ...,  1.4224,  2.2957, -0.3944],
#          [ 2.6525, -0.4972,  1.7572,  ...,  0.0954, -0.4087, -0.5127],
#          [-0.6099,  1.3736, -0.4484,  ...,  1.0382, -0.3736, -1.4498],
#          ...,
#          [ 0.2059,  0.4491, -1.7673,  ..., -0.4939,  0.3272, -0.9960],
#          [ 0.8828,  0.0485, -1.8293,  ..., -0.2453,  0.9305, -1.6672],
#          [-0.9344,  0.7967, -0.4213,  ...,  0.8275, -0.8511, -1.0107]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 2
# inputs= tensor([[[-0.9681,  0.2716,  1.4775,  ...,  1.4349, -0.4828, -2.3926],
#          [-1.9622,  1.5685, -0.3171,  ..., -1.3052,  0.7432,  0.2840],
#          [-0.3171, -1.1408,  0.8333,  ..., -0.0348,  0.1850,  0.9617],
#          ...,
#          [-1.1376, -0.0100,  0.7508,  ...,  0.2652,  0.7560, -0.2433],
#          [-2.0999,  0.9153, -0.3850,  ...,  0.4209,  0.6160,  0.0331],
#          [ 0.0519, -1.1740,  2.9918,  ...,  0.3874, -0.9176,  1.0621]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 3
# inputs= tensor([[[ 1.4751, -2.2790, -0.5338,  ..., -0.2522, -0.2616, -1.3452],
#          [ 0.3894,  1.0400, -0.5621,  ..., -0.7888,  0.2940, -1.3033],
#          [-1.3584, -0.2238, -2.6254,  ..., -0.6882, -0.4461,  0.0454],
#          ...,
#          [-0.2897,  0.7729, -0.4392,  ...,  0.5651, -1.3621, -0.3709],
#          [-1.3717, -1.3365, -0.6513,  ..., -0.4769,  0.2960,  0.5230],
#          [ 0.3976, -0.3644,  1.9948,  ...,  1.6095, -0.6920,  0.7229]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# Epoch [8/10], Loss: 559.625
# ------------------------------------------------------
# i= 0
# inputs= tensor([[[-0.2619, -0.6147,  0.7968,  ..., -0.2643,  1.1212,  0.7796],
#          [-0.1804, -0.4150, -0.6541,  ...,  0.7962,  1.4538, -1.2213],
#          [-1.0690, -0.1759, -0.7373,  ..., -0.1449,  1.4295, -1.4209],
#          ...,
#          [-0.3537, -0.8999, -1.2690,  ...,  0.8678,  1.3526,  1.7176],
#          [ 1.4875,  0.1943, -2.9266,  ...,  1.3069, -0.1743,  0.8847],
#          [ 0.1588,  0.0406,  1.1313,  ..., -0.2899, -0.9426,  0.9801]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 1
# inputs= tensor([[[ 0.4778,  1.3883, -0.8741,  ...,  1.4224,  2.2957, -0.3944],
#          [ 2.6525, -0.4972,  1.7572,  ...,  0.0954, -0.4087, -0.5127],
#          [-0.6099,  1.3736, -0.4484,  ...,  1.0382, -0.3736, -1.4498],
#          ...,
#          [ 0.2059,  0.4491, -1.7673,  ..., -0.4939,  0.3272, -0.9960],
#          [ 0.8828,  0.0485, -1.8293,  ..., -0.2453,  0.9305, -1.6672],
#          [-0.9344,  0.7967, -0.4213,  ...,  0.8275, -0.8511, -1.0107]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 2
# inputs= tensor([[[-0.9681,  0.2716,  1.4775,  ...,  1.4349, -0.4828, -2.3926],
#          [-1.9622,  1.5685, -0.3171,  ..., -1.3052,  0.7432,  0.2840],
#          [-0.3171, -1.1408,  0.8333,  ..., -0.0348,  0.1850,  0.9617],
#          ...,
#          [-1.1376, -0.0100,  0.7508,  ...,  0.2652,  0.7560, -0.2433],
#          [-2.0999,  0.9153, -0.3850,  ...,  0.4209,  0.6160,  0.0331],
#          [ 0.0519, -1.1740,  2.9918,  ...,  0.3874, -0.9176,  1.0621]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 3
# inputs= tensor([[[ 1.4751, -2.2790, -0.5338,  ..., -0.2522, -0.2616, -1.3452],
#          [ 0.3894,  1.0400, -0.5621,  ..., -0.7888,  0.2940, -1.3033],
#          [-1.3584, -0.2238, -2.6254,  ..., -0.6882, -0.4461,  0.0454],
#          ...,
#          [-0.2897,  0.7729, -0.4392,  ...,  0.5651, -1.3621, -0.3709],
#          [-1.3717, -1.3365, -0.6513,  ..., -0.4769,  0.2960,  0.5230],
#          [ 0.3976, -0.3644,  1.9948,  ...,  1.6095, -0.6920,  0.7229]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# Epoch [9/10], Loss: 559.625
# ------------------------------------------------------
# i= 0
# inputs= tensor([[[-0.2619, -0.6147,  0.7968,  ..., -0.2643,  1.1212,  0.7796],
#          [-0.1804, -0.4150, -0.6541,  ...,  0.7962,  1.4538, -1.2213],
#          [-1.0690, -0.1759, -0.7373,  ..., -0.1449,  1.4295, -1.4209],
#          ...,
#          [-0.3537, -0.8999, -1.2690,  ...,  0.8678,  1.3526,  1.7176],
#          [ 1.4875,  0.1943, -2.9266,  ...,  1.3069, -0.1743,  0.8847],
#          [ 0.1588,  0.0406,  1.1313,  ..., -0.2899, -0.9426,  0.9801]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 1
# inputs= tensor([[[ 0.4778,  1.3883, -0.8741,  ...,  1.4224,  2.2957, -0.3944],
#          [ 2.6525, -0.4972,  1.7572,  ...,  0.0954, -0.4087, -0.5127],
#          [-0.6099,  1.3736, -0.4484,  ...,  1.0382, -0.3736, -1.4498],
#          ...,
#          [ 0.2059,  0.4491, -1.7673,  ..., -0.4939,  0.3272, -0.9960],
#          [ 0.8828,  0.0485, -1.8293,  ..., -0.2453,  0.9305, -1.6672],
#          [-0.9344,  0.7967, -0.4213,  ...,  0.8275, -0.8511, -1.0107]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 2
# inputs= tensor([[[-0.9681,  0.2716,  1.4775,  ...,  1.4349, -0.4828, -2.3926],
#          [-1.9622,  1.5685, -0.3171,  ..., -1.3052,  0.7432,  0.2840],
#          [-0.3171, -1.1408,  0.8333,  ..., -0.0348,  0.1850,  0.9617],
#          ...,
#          [-1.1376, -0.0100,  0.7508,  ...,  0.2652,  0.7560, -0.2433],
#          [-2.0999,  0.9153, -0.3850,  ...,  0.4209,  0.6160,  0.0331],
#          [ 0.0519, -1.1740,  2.9918,  ...,  0.3874, -0.9176,  1.0621]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# i= 3
# inputs= tensor([[[ 1.4751, -2.2790, -0.5338,  ..., -0.2522, -0.2616, -1.3452],
#          [ 0.3894,  1.0400, -0.5621,  ..., -0.7888,  0.2940, -1.3033],
#          [-1.3584, -0.2238, -2.6254,  ..., -0.6882, -0.4461,  0.0454],
#          ...,
#          [-0.2897,  0.7729, -0.4392,  ...,  0.5651, -1.3621, -0.3709],
#          [-1.3717, -1.3365, -0.6513,  ..., -0.4769,  0.2960,  0.5230],
#          [ 0.3976, -0.3644,  1.9948,  ...,  1.6095, -0.6920,  0.7229]]],
#        requires_grad=True)
# predicted spans:  tensor([[0., -0.]], grad_fn=<RoundBackward0>)
# Epoch [10/10], Loss: 559.625
# ------------------------------------------------------

# %% [markdown]
# ### Training for 1 meeting

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

corpus_root = 'drive/My Drive/Colab Notebooks/datasets/'
# Out:
# Mounted at /content/drive

# %%
corpus_root_DS = 'drive/My Drive/Colab Notebooks/Data Science (Final Project)/CNN/'

# tensor_dict = torch.load(corpus_root_DS+'dictionary.pt')
new_tensor_dict = torch.load(corpus_root_DS+'VAL_TENSOR_ROBERTA.pt', map_location=torch.device('cpu')) # training with cpu
# new_tensor_dict = torch.load(corpus_root_DS+'dictionary_final_lc_ELECTRA.pt')

# print(tensor_dict)
# print(len(new_tensor_dict))
# print(new_tensor_dict['Meeting 156']['Length'])

# %%
print(new_tensor_dict.keys())
# Out:
# dict_keys(['meeting: ES2011b.json', 'meeting: Bed008.json', 'meeting: IS1003b.json', 'meeting: ES2011d.json', 'meeting: ES2004c.json', 'meeting: Bmr006.json', 'meeting: TS3004a.json', 'meeting: IS1003a.json', 'meeting: education_13.json', 'meeting: covid_4.json', 'meeting: covid_9.json', 'meeting: education_9.json', 'meeting: education_4.json', 'meeting: education_17.json', 'meeting: Bmr014.json', 'meeting: TS3004d.json', 'meeting: Bed003.json', 'meeting: TS3011b.json', 'meeting: IS1003d.json', 'meeting: Bro004.json', 'meeting: TS3004b.json', 'meeting: Bro027.json', 'meeting: ES2004b.json', 'meeting: TS3004c.json', 'meeting: IS1003c.json', 'meeting: Bed016.json', 'meeting: TS3011c.json', 'meeting: ES2011c.json', 'meeting: TS3011a.json', 'meeting: TS3011d.json', 'meeting: ES2004a.json', 'meeting: ES2011a.json', 'meeting: ES2004d.json', 'meeting: Bro019.json', 'meeting: Bmr023.json'])

# %%
print(new_tensor_dict['meeting: Bed008.json']['Meeting 0']['Transcript'])
print(new_tensor_dict['meeting: IS1003b.json']['Meeting 0'].keys())
print(new_tensor_dict['meeting: IS1003b.json'].keys())
print(new_tensor_dict.keys())
# Out:
# tensor([[[-0.1095,  0.0869,  0.1253,  ...,  0.0619, -0.2003,  0.1820],
#          [-0.2126, -0.0530, -0.1508,  ..., -0.0317, -0.4251, -0.0024],
#          [ 0.0358,  0.2351, -0.0924,  ..., -0.3321, -0.3012, -0.0865],
#          ...,
#          [ 0.3888, -0.3714, -0.0690,  ...,  0.5387,  0.4168, -0.5220],
#          [ 0.3570, -0.3428, -0.0045,  ...,  0.5750,  0.3514, -0.5224],
#          [-0.1269,  0.0083, -0.0225,  ...,  0.1302, -0.1517,  0.0016]]],
#        requires_grad=True)
# dict_keys(['Length', 'Transcript', 'Query', 'Spans'])
# dict_keys(['Meeting 0'])
# dict_keys(['meeting: ES2011b.json', 'meeting: Bed008.json', 'meeting: IS1003b.json', 'meeting: ES2011d.json', 'meeting: ES2004c.json', 'meeting: Bmr006.json', 'meeting: TS3004a.json', 'meeting: IS1003a.json', 'meeting: education_13.json', 'meeting: covid_4.json', 'meeting: covid_9.json', 'meeting: education_9.json', 'meeting: education_4.json', 'meeting: education_17.json', 'meeting: Bmr014.json', 'meeting: TS3004d.json', 'meeting: Bed003.json', 'meeting: TS3011b.json', 'meeting: IS1003d.json', 'meeting: Bro004.json', 'meeting: TS3004b.json', 'meeting: Bro027.json', 'meeting: ES2004b.json', 'meeting: TS3004c.json', 'meeting: IS1003c.json', 'meeting: Bed016.json', 'meeting: TS3011c.json', 'meeting: ES2011c.json', 'meeting: TS3011a.json', 'meeting: TS3011d.json', 'meeting: ES2004a.json', 'meeting: ES2011a.json', 'meeting: ES2004d.json', 'meeting: Bro019.json', 'meeting: Bmr023.json'])

# %%
print(tensor_dict['Query'][0].is_cuda)
# Out:
# False

# %% [markdown]
# ### Train 1 meeting

# %%
# Training test from dictionary.pt (1 meeting)
writer = SummaryWriter()

transcript_emb = tensor_dict['Transcript']
query_set = tensor_dict['Query']
start_end_label = tensor_dict['Spans'] #label

# Instantiate Locater
input_dim = 50*2  # Dimension after connected
hidden_dim = 128
output_dim = 2  # output <start, end> spans
locater = Locater(input_dim, hidden_dim, output_dim)


# Loss function
# criterion = nn.CrossEntropyLoss()  # can't work
# criterion = nn.MSELoss()  
# criterion = nn.L1Loss()
criterion = nn.SmoothL1Loss()

# Optimizer
from torch import optim
# optimizer = optim.Adam(locater.parameters(), lr=0.001)
optimizer = optim.AdamW(locater.parameters(), lr=0.001)

num_epochs = 20

for epoch in tqdm(range(num_epochs)):
  running_loss = 0.0
  for i, (inputs_query, label) in enumerate(zip(query_set, start_end_label)):
    print('i=',i)
    # print('inputs=',inputs_query)

    # 前向传播
    spans = locater(transcript_emb, inputs_query)
    loss = criterion(spans.squeeze(dim=0), label)  # 计算loss误差
    spans.requires_grad_(True)

    print('predicted spans: ', spans.squeeze(dim=0))

    # 反向传播和优化
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    running_loss += loss.item()
  
  
    # 打印每个epoch的平均损失
  epoch_loss = running_loss / len(query_set)
  print(f" Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss} ")
  print('======================================================')
  print()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# i= 0
# predicted spans:  tensor([0.0029, 0.0693], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([3.1264, 4.1405], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([18.1007, 20.4746], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([45.8711, 52.6227], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([ 91.4300, 101.5358], grad_fn=<SqueezeBackward1>)
# i= 5
# predicted spans:  tensor([150.2351, 158.4020], grad_fn=<SqueezeBackward1>)
#   5%|▌         | 1/20 [00:01<00:28,  1.52s/it]
#  Epoch [1/20], Loss: 159.12432734171549
# ======================================================
#
# i= 0
# predicted spans:  tensor([277.2852, 288.8856], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([295.0707, 304.9908], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([262.3362, 271.5877], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([211.1555, 222.2758], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([166.6828, 198.1040], grad_fn=<SqueezeBackward1>)
# i= 5
# predicted spans:  tensor([142.9354, 182.9619], grad_fn=<SqueezeBackward1>)
#  10%|█         | 2/20 [00:02<00:26,  1.48s/it]
#  Epoch [2/20], Loss: 196.61265309651694
# ======================================================
#
# i= 0
# predicted spans:  tensor([132.8606, 196.6265], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([124.2155, 194.7906], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([106.4772, 179.4150], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([ 79.0628, 171.1845], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([ 77.8639, 180.4614], grad_fn=<SqueezeBackward1>)
# i= 5
# predicted spans:  tensor([ 80.1653, 189.2145], grad_fn=<SqueezeBackward1>)
#  15%|█▌        | 3/20 [00:04<00:25,  1.48s/it]
#  Epoch [3/20], Loss: 159.716921488444
# ======================================================
#
# i= 0
# predicted spans:  tensor([ 62.7230, 196.8436], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([ 67.5945, 214.4763], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([ 63.3274, 222.2055], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([ 52.7813, 205.8163], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([ 67.7884, 215.2268], grad_fn=<SqueezeBackward1>)
# i= 5
# predicted spans:  tensor([ 87.6724, 226.2238], grad_fn=<SqueezeBackward1>)
#  20%|██        | 4/20 [00:05<00:21,  1.35s/it]
#  Epoch [4/20], Loss: 142.8383525212606
# ======================================================
#
# i= 0
# predicted spans:  tensor([ 61.0055, 210.4916], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([ 78.8297, 232.5424], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([ 93.1803, 245.7586], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([ 72.7943, 222.4083], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([ 90.6163, 233.1966], grad_fn=<SqueezeBackward1>)
# i= 5
# predicted spans:  tensor([116.2414, 250.2220], grad_fn=<SqueezeBackward1>)
#  25%|██▌       | 5/20 [00:06<00:19,  1.28s/it]
#  Epoch [5/20], Loss: 139.77740605672201
# ======================================================
#
# i= 0
# predicted spans:  tensor([ 57.2374, 203.3742], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([ 82.2189, 231.5686], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([106.0460, 255.1878], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([ 80.9310, 229.8374], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([105.8539, 246.8605], grad_fn=<SqueezeBackward1>)
# i= 5
#  30%|███       | 6/20 [00:07<00:17,  1.24s/it]
# predicted spans:  tensor([143.7714, 276.7004], grad_fn=<SqueezeBackward1>)
#  Epoch [6/20], Loss: 132.72319348653158
# ======================================================
#
# i= 0
# predicted spans:  tensor([ 42.7896, 188.0005], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([ 77.8091, 227.5432], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([115.6057, 266.9289], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([ 84.2780, 238.7482], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([122.0007, 266.5358], grad_fn=<SqueezeBackward1>)
# i= 5
#  35%|███▌      | 7/20 [00:09<00:15,  1.22s/it]
# predicted spans:  tensor([184.0380, 319.5281], grad_fn=<SqueezeBackward1>)
#  Epoch [7/20], Loss: 120.37901624043782
# ======================================================
#
# i= 0
# predicted spans:  tensor([ 22.8353, 163.6276], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([ 71.1398, 223.2010], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([135.0935, 286.8292], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([ 99.3080, 252.9152], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([152.0494, 265.0077], grad_fn=<SqueezeBackward1>)
# i= 5
# predicted spans:  tensor([250.1998, 330.0775], grad_fn=<SqueezeBackward1>)
#  40%|████      | 8/20 [00:10<00:14,  1.21s/it]
#  Epoch [8/20], Loss: 108.4999345143636
# ======================================================
#
# i= 0
# predicted spans:  tensor([11.2616, 57.0320], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([ 64.4046, 117.0545], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([161.7785, 201.6766], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([126.3252, 146.3518], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([218.4355, 223.1393], grad_fn=<SqueezeBackward1>)
#  45%|████▌     | 9/20 [00:11<00:13,  1.18s/it]
# i= 5
# predicted spans:  tensor([375.4038, 363.5595], grad_fn=<SqueezeBackward1>)
#  Epoch [9/20], Loss: 75.08273474375407
# ======================================================
#
# i= 0
# predicted spans:  tensor([43.5548, 61.1972], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([110.6614,  82.0781], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([267.6708, 261.2396], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([237.1729, 231.8964], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([346.5761, 356.6199], grad_fn=<SqueezeBackward1>)
#  50%|█████     | 10/20 [00:12<00:11,  1.17s/it]
# i= 5
# predicted spans:  tensor([518.4061, 553.7761], grad_fn=<SqueezeBackward1>)
#  Epoch [10/20], Loss: 60.23472913106283
# ======================================================
#
# i= 0
# predicted spans:  tensor([65.1389, 76.7626], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([32.5280,  4.2682], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([ 46.2113, 179.3389], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([ 50.3191, 208.1118], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([167.9173, 363.1923], grad_fn=<SqueezeBackward1>)
# i= 5
# predicted spans:  tensor([365.7555, 580.6998], grad_fn=<SqueezeBackward1>)
#  55%|█████▌    | 11/20 [00:13<00:10,  1.16s/it]
#  Epoch [11/20], Loss: 65.32991377512614
# ======================================================
#
# i= 0
# predicted spans:  tensor([ 27.8716, 103.0100], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([ 52.0284, 217.2471], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([219.1190, 388.8535], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([238.8380, 381.8317], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([312.2619, 432.5737], grad_fn=<SqueezeBackward1>)
# i= 5
# predicted spans:  tensor([400.5228, 506.3458], grad_fn=<SqueezeBackward1>)
#  60%|██████    | 12/20 [00:15<00:10,  1.26s/it]
#  Epoch [12/20], Loss: 72.60446866353352
# ======================================================
#
# i= 0
# predicted spans:  tensor([48.9929, 64.1287], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([ 74.3515, 101.2959], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([125.9869, 177.1232], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([104.6145, 153.5755], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([177.2158, 227.2640], grad_fn=<SqueezeBackward1>)
# i= 5
# predicted spans:  tensor([283.5663, 318.0385], grad_fn=<SqueezeBackward1>)
#  65%|██████▌   | 13/20 [00:16<00:09,  1.33s/it]
#  Epoch [13/20], Loss: 91.02984301249187
# ======================================================
#
# i= 0
# predicted spans:  tensor([1.7987, 1.6867], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([18.7487, 45.8664], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([131.7638, 195.3521], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([144.2864, 208.9271], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([280.5299, 342.2043], grad_fn=<SqueezeBackward1>)
# i= 5
# predicted spans:  tensor([456.8917, 494.7836], grad_fn=<SqueezeBackward1>)
#  70%|███████   | 14/20 [00:18<00:08,  1.38s/it]
#  Epoch [14/20], Loss: 31.99914614359538
# ======================================================
#
# i= 0
# predicted spans:  tensor([23.9573, 42.8029], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([108.8705, 174.9846], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([303.0322, 385.0316], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([316.0319, 391.2421], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([465.4420, 532.1199], grad_fn=<SqueezeBackward1>)
# i= 5
#  75%|███████▌  | 15/20 [00:19<00:06,  1.40s/it]
# predicted spans:  tensor([603.5120, 621.9384], grad_fn=<SqueezeBackward1>)
#  Epoch [15/20], Loss: 116.83044099807739
# ======================================================
#
# i= 0
# predicted spans:  tensor([ 41.9452, 110.6205], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([24.7881, 75.7924], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([ 8.8261, 22.2317], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([27.0840, 30.8781], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([ 33.7930, 131.0851], grad_fn=<SqueezeBackward1>)
# i= 5
#  80%|████████  | 16/20 [00:20<00:05,  1.32s/it]
# predicted spans:  tensor([205.6203, 256.8073], grad_fn=<SqueezeBackward1>)
#  Epoch [16/20], Loss: 153.52037239074707
# ======================================================
#
# i= 0
# predicted spans:  tensor([54.9526,  7.2816], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([63.4873, 37.9774], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([42.9915, 82.2832], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([ 34.1807, 106.4560], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([ 43.2029, 192.6434], grad_fn=<SqueezeBackward1>)
# i= 5
#  85%|████████▌ | 17/20 [00:21<00:03,  1.28s/it]
# predicted spans:  tensor([216.9393, 302.9457], grad_fn=<SqueezeBackward1>)
#  Epoch [17/20], Loss: 124.87818400065105
# ======================================================
#
# i= 0
# predicted spans:  tensor([ 20.5037, 144.9452], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([ 33.3673, 144.7903], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([  3.7868, 195.7876], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([  4.7459, 201.4151], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([152.4796, 326.0896], grad_fn=<SqueezeBackward1>)
# i= 5
# predicted spans:  tensor([366.0160, 464.0138], grad_fn=<SqueezeBackward1>)
#  90%|█████████ | 18/20 [00:23<00:02,  1.24s/it]
#  Epoch [18/20], Loss: 77.59272193908691
# ======================================================
#
# i= 0
# predicted spans:  tensor([  7.0631, 100.9905], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([ 15.0573, 174.6504], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([167.9220, 326.5852], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([205.5013, 329.2081], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([395.0829, 485.9073], grad_fn=<SqueezeBackward1>)
# i= 5
# predicted spans:  tensor([570.8956, 601.6559], grad_fn=<SqueezeBackward1>)
#  95%|█████████▌| 19/20 [00:24<00:01,  1.24s/it]
#  Epoch [19/20], Loss: 74.28375434875488
# ======================================================
#
# i= 0
# predicted spans:  tensor([12.9865, 40.0610], grad_fn=<SqueezeBackward1>)
# i= 1
# predicted spans:  tensor([15.4401,  0.2108], grad_fn=<SqueezeBackward1>)
# i= 2
# predicted spans:  tensor([52.1966, 47.7288], grad_fn=<SqueezeBackward1>)
# i= 3
# predicted spans:  tensor([62.9014, 38.6816], grad_fn=<SqueezeBackward1>)
# i= 4
# predicted spans:  tensor([193.1124, 170.7258], grad_fn=<SqueezeBackward1>)
# i= 5
# predicted spans:  tensor([331.5782, 300.7635], grad_fn=<SqueezeBackward1>)
# 100%|██████████| 20/20 [00:25<00:00,  1.28s/it]
#  Epoch [20/20], Loss: 109.72569886843364
# ======================================================

# %% [markdown]
# ### Train ALL meeting

# %%
# Training test from dictionary_final_lc.pt 

# This is for model summary(Not done yet)
writer = SummaryWriter()

# Instantiate Locater
input_dim = 2+(50*2)  # Dimension after connected
hidden_dim = 128
output_dim = 2  # output <start, end> spans
locater = Locater(input_dim, hidden_dim, output_dim)


# Loss function
# criterion = nn.CrossEntropyLoss()  # can't work
# criterion = nn.MSELoss()  
# criterion = nn.L1Loss()
criterion = nn.SmoothL1Loss()
# criterion = nn.CosineEmbeddingLoss()
# loss_range = torch.tensor([-1, 1]) # CosineEmbeddingLoss need to define range of similarity


# Optimizer
from torch import optim
# optimizer = optim.Adam(locater.parameters(), lr=0.001)
optimizer = optim.AdamW(locater.parameters(), lr=1e-5)

num_epochs = 10

for epoch in tqdm(range(num_epochs)):  # iterate epochs
  for meeting_num, meeting in new_tensor_dict.items():  # iterate meeting for an epoch

    # Get training data for one meeting
    transcript_emb = meeting['Transcript']
    query_set = meeting['Query']
    start_end_label = meeting['Spans'] #label
    meeting_len = meeting['Length'] # meeting length

    running_loss = 0.0

    for i, (inputs_query, label) in enumerate(zip(query_set, start_end_label)):  # iterate query for a meeting

      transcript_emb = transcript_emb.to('cpu')
      inputs_query = inputs_query.to('cpu')
      label = label.to('cpu')

      # 前向传播
      spans = locater(transcript_emb, inputs_query, meeting_len)
      loss = criterion(spans.squeeze(dim=0), label)  # 计算loss误差  (大部分loss function用這個)
      # loss = criterion(spans, label.unsqueeze(1), loss_range)  # 计算loss误差  (CosineEmbeddingLoss用這個)
      spans.requires_grad_(True)

      print('Meeting=',meeting_num, ' Query=',i,'  Predicted spans: ', spans.squeeze(dim=0), ' len=',meeting_len)

      # 反向传播和优化
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      
      running_loss += loss.item()
  
    print(" ")

    # 打印每个epoch的平均损失
  epoch_loss = running_loss / len(query_set)
  print(f" Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss} ")
  print('======================================================')
  print(" ")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Meeting= Meeting 0  Query= 0   Predicted spans:  tensor([4.1199, 3.1364], grad_fn=<SqueezeBackward1>)  len= 178
# Meeting= Meeting 0  Query= 1   Predicted spans:  tensor([3.6990, 3.6026], grad_fn=<SqueezeBackward1>)  len= 178
# Meeting= Meeting 0  Query= 2   Predicted spans:  tensor([3.5947, 4.0645], grad_fn=<SqueezeBackward1>)  len= 178
# Meeting= Meeting 0  Query= 3   Predicted spans:  tensor([3.5934, 4.4931], grad_fn=<SqueezeBackward1>)  len= 178
# Meeting= Meeting 0  Query= 4   Predicted spans:  tensor([3.6547, 4.8937], grad_fn=<SqueezeBackward1>)  len= 178
# Meeting= Meeting 0  Query= 5   Predicted spans:  tensor([3.7477, 5.2890], grad_fn=<SqueezeBackward1>)  len= 178
#
# Meeting= Meeting 1  Query= 0   Predicted spans:  tensor([5.7288, 7.1320], grad_fn=<SqueezeBackward1>)  len= 258
# Meeting= Meeting 1  Query= 1   Predicted spans:  tensor([5.8590, 7.4861], grad_fn=<SqueezeBackward1>)  len= 258
# Meeting= Meeting 1  Query= 2   Predicted spans:  tensor([6.0290, 7.9056], grad_fn=<SqueezeBackward1>)  len= 258
# Meeting= Meeting 1  Query= 3   Predicted spans:  tensor([6.2243, 8.2926], grad_fn=<SqueezeBackward1>)  len= 258
# Meeting= Meeting 1  Query= 4   Predicted spans:  tensor([6.4023, 8.6775], grad_fn=<SqueezeBackward1>)  len= 258
# Meeting= Meeting 1  Query= 5   Predicted spans:  tensor([6.6254, 9.0273], grad_fn=<SqueezeBackward1>)  len= 258
#
# Meeting= Meeting 2  Query= 0   Predicted spans:  tensor([3.4600, 6.0378], grad_fn=<SqueezeBackward1>)  len= 111
# Meeting= Meeting 2  Query= 1   Predicted spans:  tensor([3.7206, 6.1973], grad_fn=<SqueezeBackward1>)  len= 111
# Meeting= Meeting 2  Query= 2   Predicted spans:  tensor([3.9839, 6.3922], grad_fn=<SqueezeBackward1>)  len= 111
# Meeting= Meeting 2  Query= 3   Predicted spans:  tensor([4.2662, 6.5947], grad_fn=<SqueezeBackward1>)  len= 111
# Meeting= Meeting 2  Query= 4   Predicted spans:  tensor([4.5614, 6.8070], grad_fn=<SqueezeBackward1>)  len= 111
# Meeting= Meeting 2  Query= 5   Predicted spans:  tensor([4.8663, 7.0116], grad_fn=<SqueezeBackward1>)  len= 111
# Meeting= Meeting 2  Query= 6   Predicted spans:  tensor([5.1652, 7.2292], grad_fn=<SqueezeBackward1>)  len= 111
# Meeting= Meeting 2  Query= 7   Predicted spans:  tensor([5.4491, 7.4613], grad_fn=<SqueezeBackward1>)  len= 111
# Meeting= Meeting 2  Query= 8   Predicted spans:  tensor([5.7758, 7.8323], grad_fn=<SqueezeBackward1>)  len= 111
# Meeting= Meeting 2  Query= 9   Predicted spans:  tensor([6.1373, 8.1454], grad_fn=<SqueezeBackward1>)  len= 111
# Meeting= Meeting 2  Query= 10   Predicted spans:  tensor([6.3876, 8.3080], grad_fn=<SqueezeBackward1>)  len= 111
# Meeting= Meeting 2  Query= 11   Predicted spans:  tensor([6.7553, 8.8426], grad_fn=<SqueezeBackward1>)  len= 111
#
# Meeting= Meeting 3  Query= 0   Predicted spans:  tensor([16.5650, 18.2859], grad_fn=<SqueezeBackward1>)  len= 510
# Meeting= Meeting 3  Query= 1   Predicted spans:  tensor([16.9138, 18.6321], grad_fn=<SqueezeBackward1>)  len= 510
# Meeting= Meeting 3  Query= 2   Predicted spans:  tensor([17.2966, 19.0295], grad_fn=<SqueezeBackward1>)  len= 510
# Meeting= Meeting 3  Query= 3   Predicted spans:  tensor([17.8068, 19.5965], grad_fn=<SqueezeBackward1>)  len= 510
# Meeting= Meeting 3  Query= 4   Predicted spans:  tensor([18.2174, 19.9678], grad_fn=<SqueezeBackward1>)  len= 510
# Meeting= Meeting 3  Query= 5   Predicted spans:  tensor([18.7800, 20.5695], grad_fn=<SqueezeBackward1>)  len= 510
#
# Meeting= Meeting 4  Query= 0   Predicted spans:  tensor([16.6977, 18.8541], grad_fn=<SqueezeBackward1>)  len= 409
# Meeting= Meeting 4  Query= 1   Predicted spans:  tensor([16.9511, 19.4302], grad_fn=<SqueezeBackward1>)  len= 409
# Meeting= Meeting 4  Query= 2   Predicted spans:  tensor([17.2572, 20.0045], grad_fn=<SqueezeBackward1>)  len= 409
# Meeting= Meeting 4  Query= 3   Predicted spans:  tensor([17.5674, 20.5961], grad_fn=<SqueezeBackward1>)  len= 409
# Meeting= Meeting 4  Query= 4   Predicted spans:  tensor([17.8376, 21.1492], grad_fn=<SqueezeBackward1>)  len= 409
# Meeting= Meeting 4  Query= 5   Predicted spans:  tensor([18.3335, 21.8509], grad_fn=<SqueezeBackward1>)  len= 409
#
# Meeting= Meeting 5  Query= 0   Predicted spans:  tensor([14.6779, 18.4321], grad_fn=<SqueezeBackward1>)  len= 243
# Meeting= Meeting 5  Query= 1   Predicted spans:  tensor([15.0381, 18.8817], grad_fn=<SqueezeBackward1>)  len= 243
# Meeting= Meeting 5  Query= 2   Predicted spans:  tensor([15.5386, 19.6500], grad_fn=<SqueezeBackward1>)  len= 243
# Meeting= Meeting 5  Query= 3   Predicted spans:  tensor([15.8751, 20.0595], grad_fn=<SqueezeBackward1>)  len= 243
# Meeting= Meeting 5  Query= 4   Predicted spans:  tensor([16.4536, 20.9555], grad_fn=<SqueezeBackward1>)  len= 243
# Meeting= Meeting 5  Query= 5   Predicted spans:  tensor([16.9017, 21.4946], grad_fn=<SqueezeBackward1>)  len= 243
#
# Meeting= Meeting 6  Query= 0   Predicted spans:  tensor([15.8558, 20.6820], grad_fn=<SqueezeBackward1>)  len= 194
# Meeting= Meeting 6  Query= 1   Predicted spans:  tensor([16.5229, 21.5217], grad_fn=<SqueezeBackward1>)  len= 194
# Meeting= Meeting 6  Query= 2   Predicted spans:  tensor([17.0294, 22.1163], grad_fn=<SqueezeBackward1>)  len= 194
# Meeting= Meeting 6  Query= 3   Predicted spans:  tensor([17.5021, 22.6553], grad_fn=<SqueezeBackward1>)  len= 194
# Meeting= Meeting 6  Query= 4   Predicted spans:  tensor([18.0582, 23.2540], grad_fn=<SqueezeBackward1>)  len= 194
# Meeting= Meeting 6  Query= 5   Predicted spans:  tensor([18.6368, 23.9636], grad_fn=<SqueezeBackward1>)  len= 194
#
# Meeting= Meeting 7  Query= 0   Predicted spans:  tensor([18.5959, 24.0943], grad_fn=<SqueezeBackward1>)  len= 167
# Meeting= Meeting 7  Query= 1   Predicted spans:  tensor([19.2306, 24.7401], grad_fn=<SqueezeBackward1>)  len= 167
# Meeting= Meeting 7  Query= 2   Predicted spans:  tensor([19.7593, 25.3233], grad_fn=<SqueezeBackward1>)  len= 167
# Meeting= Meeting 7  Query= 3   Predicted spans:  tensor([20.4354, 26.0398], grad_fn=<SqueezeBackward1>)  len= 167
# Meeting= Meeting 7  Query= 4   Predicted spans:  tensor([21.1839, 26.8375], grad_fn=<SqueezeBackward1>)  len= 167
#
# Meeting= Meeting 8  Query= 0   Predicted spans:  tensor([29.4332, 34.4065], grad_fn=<SqueezeBackward1>)  len= 443
# Meeting= Meeting 8  Query= 1   Predicted spans:  tensor([29.7381, 35.0322], grad_fn=<SqueezeBackward1>)  len= 443
# Meeting= Meeting 8  Query= 2   Predicted spans:  tensor([30.4451, 36.3379], grad_fn=<SqueezeBackward1>)  len= 443
# Meeting= Meeting 8  Query= 3   Predicted spans:  tensor([30.8707, 37.4022], grad_fn=<SqueezeBackward1>)  len= 443
# Meeting= Meeting 8  Query= 4   Predicted spans:  tensor([31.3692, 38.0631], grad_fn=<SqueezeBackward1>)  len= 443
# Meeting= Meeting 8  Query= 5   Predicted spans:  tensor([31.8405, 38.8656], grad_fn=<SqueezeBackward1>)  len= 443
#
# Meeting= Meeting 9  Query= 0   Predicted spans:  tensor([24.1597, 30.0154], grad_fn=<SqueezeBackward1>)  len= 89
# Meeting= Meeting 9  Query= 1   Predicted spans:  tensor([24.5513, 30.5146], grad_fn=<SqueezeBackward1>)  len= 89
# Meeting= Meeting 9  Query= 2   Predicted spans:  tensor([25.2807, 31.4365], grad_fn=<SqueezeBackward1>)  len= 89
# Meeting= Meeting 9  Query= 3   Predicted spans:  tensor([25.8127, 32.0060], grad_fn=<SqueezeBackward1>)  len= 89
# Meeting= Meeting 9  Query= 4   Predicted spans:  tensor([26.0517, 32.4595], grad_fn=<SqueezeBackward1>)  len= 89
# Meeting= Meeting 9  Query= 5   Predicted spans:  tensor([27.1279, 33.5889], grad_fn=<SqueezeBackward1>)  len= 89
#
# Meeting= Meeting 10  Query= 0   Predicted spans:  tensor([29.0498, 37.7312], grad_fn=<SqueezeBackward1>)  len= 210
# Meeting= Meeting 10  Query= 1   Predicted spans:  tensor([29.4086, 38.2052], grad_fn=<SqueezeBackward1>)  len= 210
# Meeting= Meeting 10  Query= 2   Predicted spans:  tensor([30.1574, 38.9058], grad_fn=<SqueezeBackward1>)  len= 210
# Meeting= Meeting 10  Query= 3   Predicted spans:  tensor([31.2494, 40.6608], grad_fn=<SqueezeBackward1>)  len= 210
# Meeting= Meeting 10  Query= 4   Predicted spans:  tensor([31.8900, 41.1356], grad_fn=<SqueezeBackward1>)  len= 210
# Meeting= Meeting 10  Query= 5   Predicted spans:  tensor([32.7621, 42.5048], grad_fn=<SqueezeBackward1>)  len= 210
# Meeting= Meeting 10  Query= 6   Predicted spans:  tensor([33.8692, 44.1090], grad_fn=<SqueezeBackward1>)  len= 210
# Meeting= Meeting 10  Query= 7   Predicted spans:  tensor([34.4603, 44.8297], grad_fn=<SqueezeBackward1>)  len= 210
# Meeting= Meeting 10  Query= 8   Predicted spans:  tensor([35.4825, 46.0338], grad_fn=<SqueezeBackward1>)  len= 210
# Meeting= Meeting 10  Query= 9   Predicted spans:  tensor([35.9142, 46.6658], grad_fn=<SqueezeBackward1>)  len= 210
# Meeting= Meeting 10  Query= 10   Predicted spans:  tensor([37.1761, 48.0526], grad_fn=<SqueezeBackward1>)  len= 210
# Meeting= Meeting 10  Query= 11   Predicted spans:  tensor([37.7905, 48.6910], grad_fn=<SqueezeBackward1>)  len= 210
#
# Meeting= Meeting 11  Query= 0   Predicted spans:  tensor([42.5937, 55.7124], grad_fn=<SqueezeBackward1>)  len= 337
# Meeting= Meeting 11  Query= 1   Predicted spans:  tensor([43.3775, 57.1827], grad_fn=<SqueezeBackward1>)  len= 337
# Meeting= Meeting 11  Query= 2   Predicted spans:  tensor([43.6208, 58.4107], grad_fn=<SqueezeBackward1>)  len= 337
# Meeting= Meeting 11  Query= 3   Predicted spans:  tensor([44.3754, 60.3693], grad_fn=<SqueezeBackward1>)  len= 337
#
# Meeting= Meeting 12  Query= 0   Predicted spans:  tensor([41.9779, 53.8891], grad_fn=<SqueezeBackward1>)  len= 120
# Meeting= Meeting 12  Query= 1   Predicted spans:  tensor([42.6723, 55.3861], grad_fn=<SqueezeBackward1>)  len= 120
# Meeting= Meeting 12  Query= 2   Predicted spans:  tensor([43.9180, 57.1185], grad_fn=<SqueezeBackward1>)  len= 120
# Meeting= Meeting 12  Query= 3   Predicted spans:  tensor([44.8528, 58.6180], grad_fn=<SqueezeBackward1>)  len= 120
# Meeting= Meeting 12  Query= 4   Predicted spans:  tensor([45.4597, 59.5152], grad_fn=<SqueezeBackward1>)  len= 120
# Meeting= Meeting 12  Query= 5   Predicted spans:  tensor([46.2362, 60.6798], grad_fn=<SqueezeBackward1>)  len= 120
#
# Meeting= Meeting 13  Query= 0   Predicted spans:  tensor([46.9260, 67.9844], grad_fn=<SqueezeBackward1>)  len= 235
# Meeting= Meeting 13  Query= 1   Predicted spans:  tensor([47.2003, 68.6501], grad_fn=<SqueezeBackward1>)  len= 235
# Meeting= Meeting 13  Query= 2   Predicted spans:  tensor([47.0992, 68.8727], grad_fn=<SqueezeBackward1>)  len= 235
# Meeting= Meeting 13  Query= 3   Predicted spans:  tensor([46.7367, 68.8895], grad_fn=<SqueezeBackward1>)  len= 235
# Meeting= Meeting 13  Query= 4   Predicted spans:  tensor([46.5534, 68.6471], grad_fn=<SqueezeBackward1>)  len= 235
# Meeting= Meeting 13  Query= 5   Predicted spans:  tensor([46.3452, 68.6736], grad_fn=<SqueezeBackward1>)  len= 235
#
# Meeting= Meeting 14  Query= 0   Predicted spans:  tensor([49.1269, 73.5064], grad_fn=<SqueezeBackward1>)  len= 307
# Meeting= Meeting 14  Query= 1   Predicted spans:  tensor([49.0186, 73.9898], grad_fn=<SqueezeBackward1>)  len= 307
# Meeting= Meeting 14  Query= 2   Predicted spans:  tensor([48.6549, 74.2119], grad_fn=<SqueezeBackward1>)  len= 307
# Meeting= Meeting 14  Query= 3   Predicted spans:  tensor([49.4470, 75.8293], grad_fn=<SqueezeBackward1>)  len= 307
# Meeting= Meeting 14  Query= 4   Predicted spans:  tensor([48.8991, 75.6645], grad_fn=<SqueezeBackward1>)  len= 307
# Meeting= Meeting 14  Query= 5   Predicted spans:  tensor([49.2923, 75.6030], grad_fn=<SqueezeBackward1>)  len= 307
#
# Meeting= Meeting 15  Query= 0   Predicted spans:  tensor([49.9659, 71.7092], grad_fn=<SqueezeBackward1>)  len= 150
# Meeting= Meeting 15  Query= 1   Predicted spans:  tensor([49.8321, 71.6782], grad_fn=<SqueezeBackward1>)  len= 150
# Meeting= Meeting 15  Query= 2   Predicted spans:  tensor([51.7513, 73.8946], grad_fn=<SqueezeBackward1>)  len= 150
# Meeting= Meeting 15  Query= 3   Predicted spans:  tensor([52.6956, 75.7719], grad_fn=<SqueezeBackward1>)  len= 150
# Meeting= Meeting 15  Query= 4   Predicted spans:  tensor([54.4507, 77.6913], grad_fn=<SqueezeBackward1>)  len= 150
# Meeting= Meeting 15  Query= 5   Predicted spans:  tensor([55.0181, 78.4683], grad_fn=<SqueezeBackward1>)  len= 150
#
# Meeting= Meeting 16  Query= 0   Predicted spans:  tensor([56.9605, 83.0036], grad_fn=<SqueezeBackward1>)  len= 186
# Meeting= Meeting 16  Query= 1   Predicted spans:  tensor([58.3669, 84.8358], grad_fn=<SqueezeBackward1>)  len= 186
# Meeting= Meeting 16  Query= 2   Predicted spans:  tensor([59.3780, 85.8272], grad_fn=<SqueezeBackward1>)  len= 186
# Meeting= Meeting 16  Query= 3   Predicted spans:  tensor([59.0772, 84.0406], grad_fn=<SqueezeBackward1>)  len= 186
# Meeting= Meeting 16  Query= 4   Predicted spans:  tensor([61.9551, 88.6364], grad_fn=<SqueezeBackward1>)  len= 186
# Meeting= Meeting 16  Query= 5   Predicted spans:  tensor([64.6608, 91.7742], grad_fn=<SqueezeBackward1>)  len= 186
#
# Meeting= Meeting 17  Query= 0   Predicted spans:  tensor([63.5866, 84.6997], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 17  Query= 1   Predicted spans:  tensor([64.1240, 84.9127], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 17  Query= 2   Predicted spans:  tensor([64.9164, 85.8792], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 17  Query= 3   Predicted spans:  tensor([66.1819, 86.9993], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 17  Query= 4   Predicted spans:  tensor([66.0240, 87.5197], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 17  Query= 5   Predicted spans:  tensor([65.9197, 87.5215], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 17  Query= 6   Predicted spans:  tensor([65.4860, 86.0252], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 17  Query= 7   Predicted spans:  tensor([64.6721, 85.8679], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 17  Query= 8   Predicted spans:  tensor([65.3550, 86.7621], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 17  Query= 9   Predicted spans:  tensor([65.5745, 87.0762], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 17  Query= 10   Predicted spans:  tensor([63.7262, 84.3289], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 17  Query= 11   Predicted spans:  tensor([64.2283, 84.2060], grad_fn=<SqueezeBackward1>)  len= 110
#
# Meeting= Meeting 18  Query= 0   Predicted spans:  tensor([ 68.9026, 104.3672], grad_fn=<SqueezeBackward1>)  len= 398
# Meeting= Meeting 18  Query= 1   Predicted spans:  tensor([ 69.2523, 104.2532], grad_fn=<SqueezeBackward1>)  len= 398
# Meeting= Meeting 18  Query= 2   Predicted spans:  tensor([ 70.0196, 105.1051], grad_fn=<SqueezeBackward1>)  len= 398
# Meeting= Meeting 18  Query= 3   Predicted spans:  tensor([ 70.9096, 105.8035], grad_fn=<SqueezeBackward1>)  len= 398
# Meeting= Meeting 18  Query= 4   Predicted spans:  tensor([ 71.5312, 106.3688], grad_fn=<SqueezeBackward1>)  len= 398
# Meeting= Meeting 18  Query= 5   Predicted spans:  tensor([ 72.8365, 107.2083], grad_fn=<SqueezeBackward1>)  len= 398
#
# Meeting= Meeting 19  Query= 0   Predicted spans:  tensor([ 73.9123, 103.7158], grad_fn=<SqueezeBackward1>)  len= 265
# Meeting= Meeting 19  Query= 1   Predicted spans:  tensor([ 73.6630, 103.8885], grad_fn=<SqueezeBackward1>)  len= 265
# Meeting= Meeting 19  Query= 2   Predicted spans:  tensor([ 75.4142, 104.9950], grad_fn=<SqueezeBackward1>)  len= 265
# Meeting= Meeting 19  Query= 3   Predicted spans:  tensor([ 76.5776, 105.9655], grad_fn=<SqueezeBackward1>)  len= 265
# Meeting= Meeting 19  Query= 4   Predicted spans:  tensor([ 77.0318, 106.5658], grad_fn=<SqueezeBackward1>)  len= 265
# Meeting= Meeting 19  Query= 5   Predicted spans:  tensor([ 78.2132, 107.3965], grad_fn=<SqueezeBackward1>)  len= 265
# Meeting= Meeting 19  Query= 6   Predicted spans:  tensor([ 79.6457, 108.7087], grad_fn=<SqueezeBackward1>)  len= 265
# Meeting= Meeting 19  Query= 7   Predicted spans:  tensor([ 81.7895, 110.7904], grad_fn=<SqueezeBackward1>)  len= 265
# Meeting= Meeting 19  Query= 8   Predicted spans:  tensor([ 83.5398, 112.7616], grad_fn=<SqueezeBackward1>)  len= 265
# Meeting= Meeting 19  Query= 9   Predicted spans:  tensor([ 85.2063, 114.3732], grad_fn=<SqueezeBackward1>)  len= 265
# Meeting= Meeting 19  Query= 10   Predicted spans:  tensor([ 86.8337, 116.0273], grad_fn=<SqueezeBackward1>)  len= 265
# Meeting= Meeting 19  Query= 11   Predicted spans:  tensor([ 88.1328, 117.5254], grad_fn=<SqueezeBackward1>)  len= 265
#
# Meeting= Meeting 20  Query= 0   Predicted spans:  tensor([ 89.8853, 128.3556], grad_fn=<SqueezeBackward1>)  len= 525
# Meeting= Meeting 20  Query= 1   Predicted spans:  tensor([ 91.6944, 130.8559], grad_fn=<SqueezeBackward1>)  len= 525
# Meeting= Meeting 20  Query= 2   Predicted spans:  tensor([ 94.3422, 133.4853], grad_fn=<SqueezeBackward1>)  len= 525
# Meeting= Meeting 20  Query= 3   Predicted spans:  tensor([ 96.4502, 135.9799], grad_fn=<SqueezeBackward1>)  len= 525
# Meeting= Meeting 20  Query= 4   Predicted spans:  tensor([ 98.7934, 138.8350], grad_fn=<SqueezeBackward1>)  len= 525
# Meeting= Meeting 20  Query= 5   Predicted spans:  tensor([ 99.8442, 139.9185], grad_fn=<SqueezeBackward1>)  len= 525
#
# Meeting= Meeting 21  Query= 0   Predicted spans:  tensor([103.6247, 125.9949], grad_fn=<SqueezeBackward1>)  len= 159
# Meeting= Meeting 21  Query= 1   Predicted spans:  tensor([104.4793, 127.5307], grad_fn=<SqueezeBackward1>)  len= 159
# Meeting= Meeting 21  Query= 2   Predicted spans:  tensor([105.9465, 130.7199], grad_fn=<SqueezeBackward1>)  len= 159
# Meeting= Meeting 21  Query= 3   Predicted spans:  tensor([107.0871, 132.9048], grad_fn=<SqueezeBackward1>)  len= 159
# Meeting= Meeting 21  Query= 4   Predicted spans:  tensor([108.6236, 135.5175], grad_fn=<SqueezeBackward1>)  len= 159
# Meeting= Meeting 21  Query= 5   Predicted spans:  tensor([109.5540, 137.0001], grad_fn=<SqueezeBackward1>)  len= 159
#
# Meeting= Meeting 22  Query= 0   Predicted spans:  tensor([111.4717, 161.4263], grad_fn=<SqueezeBackward1>)  len= 620
# Meeting= Meeting 22  Query= 1   Predicted spans:  tensor([113.0009, 163.9703], grad_fn=<SqueezeBackward1>)  len= 620
# Meeting= Meeting 22  Query= 2   Predicted spans:  tensor([113.7732, 165.6262], grad_fn=<SqueezeBackward1>)  len= 620
# Meeting= Meeting 22  Query= 3   Predicted spans:  tensor([116.3476, 169.7951], grad_fn=<SqueezeBackward1>)  len= 620
# Meeting= Meeting 22  Query= 4   Predicted spans:  tensor([116.8492, 170.5608], grad_fn=<SqueezeBackward1>)  len= 620
# Meeting= Meeting 22  Query= 5   Predicted spans:  tensor([118.7079, 173.5585], grad_fn=<SqueezeBackward1>)  len= 620
#
# Meeting= Meeting 23  Query= 0   Predicted spans:  tensor([122.2269, 155.3090], grad_fn=<SqueezeBackward1>)  len= 161
# Meeting= Meeting 23  Query= 1   Predicted spans:  tensor([123.9281, 157.1706], grad_fn=<SqueezeBackward1>)  len= 161
# Meeting= Meeting 23  Query= 2   Predicted spans:  tensor([125.0185, 158.7238], grad_fn=<SqueezeBackward1>)  len= 161
# Meeting= Meeting 23  Query= 3   Predicted spans:  tensor([126.4365, 160.9806], grad_fn=<SqueezeBackward1>)  len= 161
# Meeting= Meeting 23  Query= 4   Predicted spans:  tensor([127.1408, 161.8439], grad_fn=<SqueezeBackward1>)  len= 161
# Meeting= Meeting 23  Query= 5   Predicted spans:  tensor([128.3797, 162.5015], grad_fn=<SqueezeBackward1>)  len= 161
#
# Meeting= Meeting 24  Query= 0   Predicted spans:  tensor([127.0102, 170.4442], grad_fn=<SqueezeBackward1>)  len= 318
# Meeting= Meeting 24  Query= 1   Predicted spans:  tensor([127.6198, 170.4320], grad_fn=<SqueezeBackward1>)  len= 318
# Meeting= Meeting 24  Query= 2   Predicted spans:  tensor([128.4129, 171.3530], grad_fn=<SqueezeBackward1>)  len= 318
# Meeting= Meeting 24  Query= 3   Predicted spans:  tensor([130.2193, 171.7915], grad_fn=<SqueezeBackward1>)  len= 318
#
# Meeting= Meeting 25  Query= 0   Predicted spans:  tensor([132.9736, 160.2820], grad_fn=<SqueezeBackward1>)  len= 82
# Meeting= Meeting 25  Query= 1   Predicted spans:  tensor([132.2712, 157.9654], grad_fn=<SqueezeBackward1>)  len= 82
# Meeting= Meeting 25  Query= 2   Predicted spans:  tensor([136.1120, 162.8783], grad_fn=<SqueezeBackward1>)  len= 82
# Meeting= Meeting 25  Query= 3   Predicted spans:  tensor([136.4256, 161.5706], grad_fn=<SqueezeBackward1>)  len= 82
# Meeting= Meeting 25  Query= 4   Predicted spans:  tensor([137.6076, 163.0666], grad_fn=<SqueezeBackward1>)  len= 82
# Meeting= Meeting 25  Query= 5   Predicted spans:  tensor([138.0807, 163.6441], grad_fn=<SqueezeBackward1>)  len= 82
#
# Meeting= Meeting 26  Query= 0   Predicted spans:  tensor([140.0074, 167.6788], grad_fn=<SqueezeBackward1>)  len= 128
# Meeting= Meeting 26  Query= 1   Predicted spans:  tensor([138.8230, 166.7704], grad_fn=<SqueezeBackward1>)  len= 128
# Meeting= Meeting 26  Query= 2   Predicted spans:  tensor([138.4035, 166.0152], grad_fn=<SqueezeBackward1>)  len= 128
# Meeting= Meeting 26  Query= 3   Predicted spans:  tensor([138.9177, 166.2484], grad_fn=<SqueezeBackward1>)  len= 128
# Meeting= Meeting 26  Query= 4   Predicted spans:  tensor([137.6700, 165.9215], grad_fn=<SqueezeBackward1>)  len= 128
# Meeting= Meeting 26  Query= 5   Predicted spans:  tensor([136.2327, 165.3106], grad_fn=<SqueezeBackward1>)  len= 128
#
# Meeting= Meeting 27  Query= 0   Predicted spans:  tensor([137.2655, 166.1684], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 27  Query= 1   Predicted spans:  tensor([136.7755, 165.1735], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 27  Query= 2   Predicted spans:  tensor([135.6909, 164.9263], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 27  Query= 3   Predicted spans:  tensor([136.7152, 166.8453], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 27  Query= 4   Predicted spans:  tensor([137.6646, 168.5523], grad_fn=<SqueezeBackward1>)  len= 110
# Meeting= Meeting 27  Query= 5   Predicted spans:  tensor([135.8649, 167.4998], grad_fn=<SqueezeBackward1>)  len= 110
#
# Meeting= Meeting 28  Query= 0   Predicted spans:  tensor([133.5686, 167.9533], grad_fn=<SqueezeBackward1>)  len= 156
# Meeting= Meeting 28  Query= 1   Predicted spans:  tensor([131.8094, 166.7293], grad_fn=<SqueezeBackward1>)  len= 156
# Meeting= Meeting 28  Query= 2   Predicted spans:  tensor([131.5354, 167.6276], grad_fn=<SqueezeBackward1>)  len= 156
# Meeting= Meeting 28  Query= 3   Predicted spans:  tensor([129.6380, 165.9637], grad_fn=<SqueezeBackward1>)  len= 156
# Meeting= Meeting 28  Query= 4   Predicted spans:  tensor([126.7805, 162.9984], grad_fn=<SqueezeBackward1>)  len= 156
# Meeting= Meeting 28  Query= 5   Predicted spans:  tensor([129.3956, 166.8296], grad_fn=<SqueezeBackward1>)  len= 156
#
# Meeting= Meeting 29  Query= 0   Predicted spans:  tensor([128.7346, 165.0800], grad_fn=<SqueezeBackward1>)  len= 145
# Meeting= Meeting 29  Query= 1   Predicted spans:  tensor([129.2419, 167.7306], grad_fn=<SqueezeBackward1>)  len= 145
# Meeting= Meeting 29  Query= 2   Predicted spans:  tensor([127.5601, 166.3156], grad_fn=<SqueezeBackward1>)  len= 145
# Meeting= Meeting 29  Query= 3   Predicted spans:  tensor([126.0769, 164.6903], grad_fn=<SqueezeBackward1>)  len= 145
# Meeting= Meeting 29  Query= 4   Predicted spans:  tensor([125.0524, 163.4855], grad_fn=<SqueezeBackward1>)  len= 145
#
# Meeting= Meeting 30  Query= 0   Predicted spans:  tensor([123.9040, 160.7281], grad_fn=<SqueezeBackward1>)  len= 119
# Meeting= Meeting 30  Query= 1   Predicted spans:  tensor([123.1268, 160.3104], grad_fn=<SqueezeBackward1>)  len= 119
# Meeting= Meeting 30  Query= 2   Predicted spans:  tensor([123.8505, 161.5673], grad_fn=<SqueezeBackward1>)  len= 119
# Meeting= Meeting 30  Query= 3   Predicted spans:  tensor([121.7905, 158.5920], grad_fn=<SqueezeBackward1>)  len= 119
# Meeting= Meeting 30  Query= 4   Predicted spans:  tensor([121.2212, 158.3640], grad_fn=<SqueezeBackward1>)  len= 119
# Meeting= Meeting 30  Query= 5   Predicted spans:  tensor([120.3321, 157.6116], grad_fn=<SqueezeBackward1>)  len= 119
#
# Meeting= Meeting 31  Query= 0   Predicted spans:  tensor([120.6286, 185.7645], grad_fn=<SqueezeBackward1>)  len= 606
# Meeting= Meeting 31  Query= 1   Predicted spans:  tensor([120.1426, 186.0402], grad_fn=<SqueezeBackward1>)  len= 606
# Meeting= Meeting 31  Query= 2   Predicted spans:  tensor([119.5084, 184.1510], grad_fn=<SqueezeBackward1>)  len= 606
# Meeting= Meeting 31  Query= 3   Predicted spans:  tensor([119.5472, 186.3115], grad_fn=<SqueezeBackward1>)  len= 606
# Meeting= Meeting 31  Query= 4   Predicted spans:  tensor([119.3193, 185.5915], grad_fn=<SqueezeBackward1>)  len= 606
# Meeting= Meeting 31  Query= 5   Predicted spans:  tensor([119.1648, 184.6461], grad_fn=<SqueezeBackward1>)  len= 606
#
# Meeting= Meeting 32  Query= 0   Predicted spans:  tensor([118.2225, 160.8123], grad_fn=<SqueezeBackward1>)  len= 171
# Meeting= Meeting 32  Query= 1   Predicted spans:  tensor([118.3406, 161.0010], grad_fn=<SqueezeBackward1>)  len= 171
# Meeting= Meeting 32  Query= 2   Predicted spans:  tensor([114.6605, 155.9668], grad_fn=<SqueezeBackward1>)  len= 171
# Meeting= Meeting 32  Query= 3   Predicted spans:  tensor([118.0685, 162.5534], grad_fn=<SqueezeBackward1>)  len= 171
# Meeting= Meeting 32  Query= 4   Predicted spans:  tensor([117.9504, 162.7671], grad_fn=<SqueezeBackward1>)  len= 171
# Meeting= Meeting 32  Query= 5   Predicted spans:  tensor([117.5814, 162.7478], grad_fn=<SqueezeBackward1>)  len= 171
#
# Meeting= Meeting 33  Query= 0   Predicted spans:  tensor([117.9598, 159.4085], grad_fn=<SqueezeBackward1>)  len= 75
# Meeting= Meeting 33  Query= 1   Predicted spans:  tensor([116.4488, 155.3980], grad_fn=<SqueezeBackward1>)  len= 75
# Meeting= Meeting 33  Query= 2   Predicted spans:  tensor([117.8638, 159.1001], grad_fn=<SqueezeBackward1>)  len= 75
# Meeting= Meeting 33  Query= 3   Predicted spans:  tensor([117.6631, 159.4132], grad_fn=<SqueezeBackward1>)  len= 75
# Meeting= Meeting 33  Query= 4   Predicted spans:  tensor([115.8471, 157.3224], grad_fn=<SqueezeBackward1>)  len= 75
# Meeting= Meeting 33  Query= 5   Predicted spans:  tensor([116.3138, 158.0227], grad_fn=<SqueezeBackward1>)  len= 75
#
# Meeting= Meeting 34  Query= 0   Predicted spans:  tensor([116.3024, 164.8903], grad_fn=<SqueezeBackward1>)  len= 197
# Meeting= Meeting 34  Query= 1   Predicted spans:  tensor([116.4886, 164.9070], grad_fn=<SqueezeBackward1>)  len= 197
# Meeting= Meeting 34  Query= 2   Predicted spans:  tensor([115.4940, 163.5319], grad_fn=<SqueezeBackward1>)  len= 197
# Meeting= Meeting 34  Query= 3   Predicted spans:  tensor([115.2206, 163.6241], grad_fn=<SqueezeBackward1>)  len= 197
# Meeting= Meeting 34  Query= 4   Predicted spans:  tensor([114.6749, 162.7446], grad_fn=<SqueezeBackward1>)  len= 197
# Meeting= Meeting 34  Query= 5   Predicted spans:  tensor([114.8319, 162.6997], grad_fn=<SqueezeBackward1>)  len= 197
#
# Meeting= Meeting 35  Query= 0   Predicted spans:  tensor([115.4585, 158.0066], grad_fn=<SqueezeBackward1>)  len= 91
# Meeting= Meeting 35  Query= 1   Predicted spans:  tensor([114.5798, 156.6093], grad_fn=<SqueezeBackward1>)  len= 91
# Meeting= Meeting 35  Query= 2   Predicted spans:  tensor([115.4193, 157.7859], grad_fn=<SqueezeBackward1>)  len= 91
# Meeting= Meeting 35  Query= 3   Predicted spans:  tensor([115.8348, 157.9743], grad_fn=<SqueezeBackward1>)  len= 91
# Meeting= Meeting 35  Query= 4   Predicted spans:  tensor([116.8966, 158.9851], grad_fn=<SqueezeBackward1>)  len= 91
# Meeting= Meeting 35  Query= 5   Predicted spans:  tensor([118.1491, 161.3295], grad_fn=<SqueezeBackward1>)  len= 91
#
# Meeting= Meeting 36  Query= 0   Predicted spans:  tensor([120.9379, 189.1525], grad_fn=<SqueezeBackward1>)  len= 586
# Meeting= Meeting 36  Query= 1   Predicted spans:  tensor([120.9099, 189.7260], grad_fn=<SqueezeBackward1>)  len= 586
# Meeting= Meeting 36  Query= 2   Predicted spans:  tensor([122.0383, 192.3393], grad_fn=<SqueezeBackward1>)  len= 586
# Meeting= Meeting 36  Query= 3   Predicted spans:  tensor([123.8516, 195.2115], grad_fn=<SqueezeBackward1>)  len= 586
# Meeting= Meeting 36  Query= 4   Predicted spans:  tensor([122.4485, 192.9115], grad_fn=<SqueezeBackward1>)  len= 586
# Meeting= Meeting 36  Query= 5   Predicted spans:  tensor([122.4929, 193.6544], grad_fn=<SqueezeBackward1>)  len= 586
#
# Meeting= Meeting 37  Query= 0   Predicted spans:  tensor([124.0267, 176.5972], grad_fn=<SqueezeBackward1>)  len= 219
# Meeting= Meeting 37  Query= 1   Predicted spans:  tensor([124.9694, 176.6609], grad_fn=<SqueezeBackward1>)  len= 219
# Meeting= Meeting 37  Query= 2   Predicted spans:  tensor([126.5989, 179.7211], grad_fn=<SqueezeBackward1>)  len= 219
# Meeting= Meeting 37  Query= 3   Predicted spans:  tensor([124.3926, 177.6892], grad_fn=<SqueezeBackward1>)  len= 219
# Meeting= Meeting 37  Query= 4   Predicted spans:  tensor([122.6776, 173.9807], grad_fn=<SqueezeBackward1>)  len= 219
# Meeting= Meeting 37  Query= 5   Predicted spans:  tensor([127.2846, 181.1852], grad_fn=<SqueezeBackward1>)  len= 219
#
# Meeting= Meeting 38  Query= 0   Predicted spans:  tensor([127.3186, 197.3471], grad_fn=<SqueezeBackward1>)  len= 465
# Meeting= Meeting 38  Query= 1   Predicted spans:  tensor([127.3653, 195.9889], grad_fn=<SqueezeBackward1>)  len= 465
# Meeting= Meeting 38  Query= 2   Predicted spans:  tensor([128.3668, 198.3772], grad_fn=<SqueezeBackward1>)  len= 465
# Meeting= Meeting 38  Query= 3   Predicted spans:  tensor([128.3746, 198.1632], grad_fn=<SqueezeBackward1>)  len= 465
# Meeting= Meeting 38  Query= 4   Predicted spans:  tensor([129.6483, 198.7396], grad_fn=<SqueezeBackward1>)  len= 465
# Meeting= Meeting 38  Query= 5   Predicted spans:  tensor([130.8072, 199.4903], grad_fn=<SqueezeBackward1>)  len= 465
# Meeting= Meeting 38  Query= 6   Predicted spans:  tensor([130.8591, 198.9548], grad_fn=<SqueezeBackward1>)  len= 465
# Meeting= Meeting 38  Query= 7   Predicted spans:  tensor([132.0226, 200.2082], grad_fn=<SqueezeBackward1>)  len= 465
#
# Meeting= Meeting 39  Query= 0   Predicted spans:  tensor([134.8359, 197.3955], grad_fn=<SqueezeBackward1>)  len= 353
# Meeting= Meeting 39  Query= 1   Predicted spans:  tensor([134.5293, 195.9308], grad_fn=<SqueezeBackward1>)  len= 353
# Meeting= Meeting 39  Query= 2   Predicted spans:  tensor([136.0226, 197.6803], grad_fn=<SqueezeBackward1>)  len= 353
# Meeting= Meeting 39  Query= 3   Predicted spans:  tensor([138.1035, 199.9731], grad_fn=<SqueezeBackward1>)  len= 353
# Meeting= Meeting 39  Query= 4   Predicted spans:  tensor([140.2027, 201.9373], grad_fn=<SqueezeBackward1>)  len= 353
#
# Meeting= Meeting 40  Query= 0   Predicted spans:  tensor([140.8057, 185.3844], grad_fn=<SqueezeBackward1>)  len= 64
# Meeting= Meeting 40  Query= 1   Predicted spans:  tensor([140.0164, 182.7423], grad_fn=<SqueezeBackward1>)  len= 64
# Meeting= Meeting 40  Query= 2   Predicted spans:  tensor([141.8091, 184.8942], grad_fn=<SqueezeBackward1>)  len= 64
# Meeting= Meeting 40  Query= 3   Predicted spans:  tensor([143.4030, 187.4696], grad_fn=<SqueezeBackward1>)  len= 64
# Meeting= Meeting 40  Query= 4   Predicted spans:  tensor([143.6294, 186.9786], grad_fn=<SqueezeBackward1>)  len= 64
# Meeting= Meeting 40  Query= 5   Predicted spans:  tensor([142.6917, 185.6005], grad_fn=<SqueezeBackward1>)  len= 64
#
# Meeting= Meeting 41  Query= 0   Predicted spans:  tensor([141.8531, 199.1204], grad_fn=<SqueezeBackward1>)  len= 303
# Meeting= Meeting 41  Query= 1   Predicted spans:  tensor([140.4274, 196.8457], grad_fn=<SqueezeBackward1>)  len= 303
# Meeting= Meeting 41  Query= 2   Predicted spans:  tensor([139.1012, 194.9818], grad_fn=<SqueezeBackward1>)  len= 303
# Meeting= Meeting 41  Query= 3   Predicted spans:  tensor([138.8905, 196.1039], grad_fn=<SqueezeBackward1>)  len= 303
# Meeting= Meeting 41  Query= 4   Predicted spans:  tensor([137.6939, 193.3624], grad_fn=<SqueezeBackward1>)  len= 303
#
# Meeting= Meeting 42  Query= 0   Predicted spans:  tensor([137.2157, 178.0346], grad_fn=<SqueezeBackward1>)  len= 57
# Meeting= Meeting 42  Query= 1   Predicted spans:  tensor([136.1353, 177.4104], grad_fn=<SqueezeBackward1>)  len= 57
# Meeting= Meeting 42  Query= 2   Predicted spans:  tensor([133.0485, 172.3050], grad_fn=<SqueezeBackward1>)  len= 57
# Meeting= Meeting 42  Query= 3   Predicted spans:  tensor([134.5449, 175.1958], grad_fn=<SqueezeBackward1>)  len= 57
# Meeting= Meeting 42  Query= 4   Predicted spans:  tensor([130.9801, 171.0475], grad_fn=<SqueezeBackward1>)  len= 57
# Meeting= Meeting 42  Query= 5   Predicted spans:  tensor([131.5197, 171.8010], grad_fn=<SqueezeBackward1>)  len= 57
#
# Meeting= Meeting 43  Query= 0   Predicted spans:  tensor([121.8674, 163.7084], grad_fn=<SqueezeBackward1>)  len= 153
# Meeting= Meeting 43  Query= 1   Predicted spans:  tensor([120.7178, 161.8069], grad_fn=<SqueezeBackward1>)  len= 153
# Meeting= Meeting 43  Query= 2   Predicted spans:  tensor([118.6563, 158.9036], grad_fn=<SqueezeBackward1>)  len= 153
# Meeting= Meeting 43  Query= 3   Predicted spans:  tensor([117.8498, 158.7059], grad_fn=<SqueezeBackward1>)  len= 153
# Meeting= Meeting 43  Query= 4   Predicted spans:  tensor([116.5348, 157.4332], grad_fn=<SqueezeBackward1>)  len= 153
# Meeting= Meeting 43  Query= 5   Predicted spans:  tensor([114.3618, 154.6327], grad_fn=<SqueezeBackward1>)  len= 153
# Meeting= Meeting 43  Query= 6   Predicted spans:  tensor([109.8133, 148.8274], grad_fn=<SqueezeBackward1>)  len= 153
# Meeting= Meeting 43  Query= 7   Predicted spans:  tensor([112.4651, 152.1563], grad_fn=<SqueezeBackward1>)  len= 153
# Meeting= Meeting 43  Query= 8   Predicted spans:  tensor([105.6632, 144.6073], grad_fn=<SqueezeBackward1>)  len= 153
# Meeting= Meeting 43  Query= 9   Predicted spans:  tensor([106.8823, 146.4954], grad_fn=<SqueezeBackward1>)  len= 153
# Meeting= Meeting 43  Query= 10   Predicted spans:  tensor([108.7141, 148.2197], grad_fn=<SqueezeBackward1>)  len= 153
# Meeting= Meeting 43  Query= 11   Predicted spans:  tensor([106.8376, 145.9981], grad_fn=<SqueezeBackward1>)  len= 153
# Meeting= Meeting 43  Query= 12   Predicted spans:  tensor([ 99.4408, 134.7136], grad_fn=<SqueezeBackward1>)  len= 153
#
# Meeting= Meeting 44  Query= 0   Predicted spans:  tensor([113.5051, 156.0508], grad_fn=<SqueezeBackward1>)  len= 158
# Meeting= Meeting 44  Query= 1   Predicted spans:  tensor([112.5467, 153.9135], grad_fn=<SqueezeBackward1>)  len= 158
# Meeting= Meeting 44  Query= 2   Predicted spans:  tensor([111.3509, 152.1346], grad_fn=<SqueezeBackward1>)  len= 158
#
# Meeting= Meeting 45  Query= 0   Predicted spans:  tensor([112.3910, 153.4499], grad_fn=<SqueezeBackward1>)  len= 142
# Meeting= Meeting 45  Query= 1   Predicted spans:  tensor([111.7396, 152.3520], grad_fn=<SqueezeBackward1>)  len= 142
# Meeting= Meeting 45  Query= 2   Predicted spans:  tensor([111.0945, 151.4238], grad_fn=<SqueezeBackward1>)  len= 142
# Meeting= Meeting 45  Query= 3   Predicted spans:  tensor([111.1936, 150.4690], grad_fn=<SqueezeBackward1>)  len= 142
# Meeting= Meeting 45  Query= 4   Predicted spans:  tensor([110.8635, 150.0795], grad_fn=<SqueezeBackward1>)  len= 142
# Meeting= Meeting 45  Query= 5   Predicted spans:  tensor([111.5721, 150.8338], grad_fn=<SqueezeBackward1>)  len= 142
#
# Meeting= Meeting 46  Query= 0   Predicted spans:  tensor([110.1387, 154.2721], grad_fn=<SqueezeBackward1>)  len= 243
# Meeting= Meeting 46  Query= 1   Predicted spans:  tensor([111.2722, 156.7240], grad_fn=<SqueezeBackward1>)  len= 243
# Meeting= Meeting 46  Query= 2   Predicted spans:  tensor([110.7763, 156.5388], grad_fn=<SqueezeBackward1>)  len= 243
# Meeting= Meeting 46  Query= 3   Predicted spans:  tensor([112.3047, 158.3964], grad_fn=<SqueezeBackward1>)  len= 243
# Meeting= Meeting 46  Query= 4   Predicted spans:  tensor([112.4382, 158.0741], grad_fn=<SqueezeBackward1>)  len= 243
# Meeting= Meeting 46  Query= 5   Predicted spans:  tensor([113.3570, 159.7903], grad_fn=<SqueezeBackward1>)  len= 243
#
# Meeting= Meeting 47  Query= 0   Predicted spans:  tensor([114.4778, 156.4376], grad_fn=<SqueezeBackward1>)  len= 172
# Meeting= Meeting 47  Query= 1   Predicted spans:  tensor([115.6998, 157.0956], grad_fn=<SqueezeBackward1>)  len= 172
# Meeting= Meeting 47  Query= 2   Predicted spans:  tensor([116.5653, 158.6074], grad_fn=<SqueezeBackward1>)  len= 172
# Meeting= Meeting 47  Query= 3   Predicted spans:  tensor([116.0212, 158.3625], grad_fn=<SqueezeBackward1>)  len= 172
# Meeting= Meeting 47  Query= 4   Predicted spans:  tensor([116.2100, 158.0671], grad_fn=<SqueezeBackward1>)  len= 172
# Meeting= Meeting 47  Query= 5   Predicted spans:  tensor([116.3860, 157.2915], grad_fn=<SqueezeBackward1>)  len= 172
#
# Meeting= Meeting 48  Query= 0   Predicted spans:  tensor([117.2323, 160.2051], grad_fn=<SqueezeBackward1>)  len= 168
# Meeting= Meeting 48  Query= 1   Predicted spans:  tensor([117.0180, 160.3603], grad_fn=<SqueezeBackward1>)  len= 168
# Meeting= Meeting 48  Query= 2   Predicted spans:  tensor([117.5701, 160.4818], grad_fn=<SqueezeBackward1>)  len= 168
# Meeting= Meeting 48  Query= 3   Predicted spans:  tensor([118.0474, 160.2386], grad_fn=<SqueezeBackward1>)  len= 168
# Meeting= Meeting 48  Query= 4   Predicted spans:  tensor([118.3816, 161.5766], grad_fn=<SqueezeBackward1>)  len= 168
# Meeting= Meeting 48  Query= 5   Predicted spans:  tensor([117.5449, 160.4894], grad_fn=<SqueezeBackward1>)  len= 168
#
# Meeting= Meeting 49  Query= 0   Predicted spans:  tensor([113.5175, 150.0555], grad_fn=<SqueezeBackward1>)  len= 123
# Meeting= Meeting 49  Query= 1   Predicted spans:  tensor([113.7565, 148.8143], grad_fn=<SqueezeBackward1>)  len= 123
# Meeting= Meeting 49  Query= 2   Predicted spans:  tensor([114.1814, 149.8473], grad_fn=<SqueezeBackward1>)  len= 123
# Meeting= Meeting 49  Query= 3   Predicted spans:  tensor([111.7903, 147.9569], grad_fn=<SqueezeBackward1>)  len= 123
# Meeting= Meeting 49  Query= 4   Predicted spans:  tensor([113.8391, 149.1821], grad_fn=<SqueezeBackward1>)  len= 123
# Meeting= Meeting 49  Query= 5   Predicted spans:  tensor([112.6503, 147.5246], grad_fn=<SqueezeBackward1>)  len= 123
# Meeting= Meeting 49  Query= 6   Predicted spans:  tensor([110.7234, 146.6764], grad_fn=<SqueezeBackward1>)  len= 123
# Meeting= Meeting 49  Query= 7   Predicted spans:  tensor([111.4199, 146.8799], grad_fn=<SqueezeBackward1>)  len= 123
# Meeting= Meeting 49  Query= 8   Predicted spans:  tensor([106.6647, 143.4074], grad_fn=<SqueezeBackward1>)  len= 123
# Meeting= Meeting 49  Query= 9   Predicted spans:  tensor([107.9864, 144.0049], grad_fn=<SqueezeBackward1>)  len= 123
# Meeting= Meeting 49  Query= 10   Predicted spans:  tensor([107.7078, 142.9838], grad_fn=<SqueezeBackward1>)  len= 123
# Meeting= Meeting 49  Query= 11   Predicted spans:  tensor([105.2826, 138.9536], grad_fn=<SqueezeBackward1>)  len= 123
#
# Meeting= Meeting 50  Query= 0   Predicted spans:  tensor([111.5865, 157.8695], grad_fn=<SqueezeBackward1>)  len= 220
# Meeting= Meeting 50  Query= 1   Predicted spans:  tensor([109.6371, 155.4698], grad_fn=<SqueezeBackward1>)  len= 220
# Meeting= Meeting 50  Query= 2   Predicted spans:  tensor([108.4516, 154.4915], grad_fn=<SqueezeBackward1>)  len= 220
# Meeting= Meeting 50  Query= 3   Predicted spans:  tensor([107.3209, 153.2849], grad_fn=<SqueezeBackward1>)  len= 220
# Meeting= Meeting 50  Query= 4   Predicted spans:  tensor([106.5593, 152.3050], grad_fn=<SqueezeBackward1>)  len= 220
# Meeting= Meeting 50  Query= 5   Predicted spans:  tensor([105.2442, 151.1532], grad_fn=<SqueezeBackward1>)  len= 220
# Meeting= Meeting 50  Query= 6   Predicted spans:  tensor([102.6037, 148.7236], grad_fn=<SqueezeBackward1>)  len= 220
# Meeting= Meeting 50  Query= 7   Predicted spans:  tensor([101.7422, 148.2541], grad_fn=<SqueezeBackward1>)  len= 220
# Meeting= Meeting 50  Query= 8   Predicted spans:  tensor([101.2614, 149.1120], grad_fn=<SqueezeBackward1>)  len= 220
# Meeting= Meeting 50  Query= 9   Predicted spans:  tensor([ 99.1156, 145.2297], grad_fn=<SqueezeBackward1>)  len= 220
# Meeting= Meeting 50  Query= 10   Predicted spans:  tensor([ 98.9308, 147.0648], grad_fn=<SqueezeBackward1>)  len= 220
# Meeting= Meeting 50  Query= 11   Predicted spans:  tensor([ 99.7011, 147.6452], grad_fn=<SqueezeBackward1>)  len= 220
# Meeting= Meeting 50  Query= 12   Predicted spans:  tensor([ 99.8199, 148.2763], grad_fn=<SqueezeBackward1>)  len= 220
#
# Meeting= Meeting 51  Query= 0   Predicted spans:  tensor([101.7962, 163.9332], grad_fn=<SqueezeBackward1>)  len= 564
# Meeting= Meeting 51  Query= 1   Predicted spans:  tensor([101.5463, 164.9202], grad_fn=<SqueezeBackward1>)  len= 564
# Meeting= Meeting 51  Query= 2   Predicted spans:  tensor([101.5114, 163.4642], grad_fn=<SqueezeBackward1>)  len= 564
# Meeting= Meeting 51  Query= 3   Predicted spans:  tensor([101.7328, 165.1043], grad_fn=<SqueezeBackward1>)  len= 564
# Meeting= Meeting 51  Query= 4   Predicted spans:  tensor([101.9943, 163.4518], grad_fn=<SqueezeBackward1>)  len= 564
# Meeting= Meeting 51  Query= 5   Predicted spans:  tensor([103.0383, 163.9939], grad_fn=<SqueezeBackward1>)  len= 564
#
# Meeting= Meeting 52  Query= 0   Predicted spans:  tensor([102.0506, 154.9894], grad_fn=<SqueezeBackward1>)  len= 315
# Meeting= Meeting 52  Query= 1   Predicted spans:  tensor([102.3386, 155.1135], grad_fn=<SqueezeBackward1>)  len= 315
# Meeting= Meeting 52  Query= 2   Predicted spans:  tensor([102.2241, 152.7947], grad_fn=<SqueezeBackward1>)  len= 315
# Meeting= Meeting 52  Query= 3   Predicted spans:  tensor([104.6147, 155.4677], grad_fn=<SqueezeBackward1>)  len= 315
# Meeting= Meeting 52  Query= 4   Predicted spans:  tensor([105.3302, 156.0832], grad_fn=<SqueezeBackward1>)  len= 315
# Meeting= Meeting 52  Query= 5   Predicted spans:  tensor([106.7329, 158.5542], grad_fn=<SqueezeBackward1>)  len= 315
#
# Meeting= Meeting 53  Query= 0   Predicted spans:  tensor([108.0325, 163.7863], grad_fn=<SqueezeBackward1>)  len= 395
# Meeting= Meeting 53  Query= 1   Predicted spans:  tensor([109.3870, 164.9624], grad_fn=<SqueezeBackward1>)  len= 395
# Meeting= Meeting 53  Query= 2   Predicted spans:  tensor([109.0764, 163.1664], grad_fn=<SqueezeBackward1>)  len= 395
# Meeting= Meeting 53  Query= 3   Predicted spans:  tensor([110.8472, 166.2208], grad_fn=<SqueezeBackward1>)  len= 395
# Meeting= Meeting 53  Query= 4   Predicted spans:  tensor([109.4724, 162.2281], grad_fn=<SqueezeBackward1>)  len= 395
# Meeting= Meeting 53  Query= 5   Predicted spans:  tensor([112.2584, 165.8710], grad_fn=<SqueezeBackward1>)  len= 395
#
# Meeting= Meeting 54  Query= 0   Predicted spans:  tensor([114.3742, 156.5071], grad_fn=<SqueezeBackward1>)  len= 146
# Meeting= Meeting 54  Query= 1   Predicted spans:  tensor([114.3676, 156.0504], grad_fn=<SqueezeBackward1>)  len= 146
# Meeting= Meeting 54  Query= 2   Predicted spans:  tensor([116.5394, 158.5574], grad_fn=<SqueezeBackward1>)  len= 146
# Meeting= Meeting 54  Query= 3   Predicted spans:  tensor([116.9612, 159.7608], grad_fn=<SqueezeBackward1>)  len= 146
# Meeting= Meeting 54  Query= 4   Predicted spans:  tensor([117.8010, 159.8376], grad_fn=<SqueezeBackward1>)  len= 146
# Meeting= Meeting 54  Query= 5   Predicted spans:  tensor([120.1157, 162.2888], grad_fn=<SqueezeBackward1>)  len= 146
#
# Meeting= Meeting 55  Query= 0   Predicted spans:  tensor([123.8328, 186.4950], grad_fn=<SqueezeBackward1>)  len= 577
# Meeting= Meeting 55  Query= 1   Predicted spans:  tensor([125.1419, 187.3835], grad_fn=<SqueezeBackward1>)  len= 577
# Meeting= Meeting 55  Query= 2   Predicted spans:  tensor([125.5162, 188.4291], grad_fn=<SqueezeBackward1>)  len= 577
#
# Meeting= Meeting 56  Query= 0   Predicted spans:  tensor([124.5571, 178.9334], grad_fn=<SqueezeBackward1>)  len= 365
# Meeting= Meeting 56  Query= 1   Predicted spans:  tensor([126.2995, 181.0395], grad_fn=<SqueezeBackward1>)  len= 365
# Meeting= Meeting 56  Query= 2   Predicted spans:  tensor([125.9821, 181.3673], grad_fn=<SqueezeBackward1>)  len= 365
# Meeting= Meeting 56  Query= 3   Predicted spans:  tensor([127.8404, 183.6724], grad_fn=<SqueezeBackward1>)  len= 365
# Meeting= Meeting 56  Query= 4   Predicted spans:  tensor([126.4612, 180.3232], grad_fn=<SqueezeBackward1>)  len= 365
# Meeting= Meeting 56  Query= 5   Predicted spans:  tensor([129.4428, 184.1878], grad_fn=<SqueezeBackward1>)  len= 365
#
# Meeting= Meeting 57  Query= 0   Predicted spans:  tensor([129.6208, 186.5134], grad_fn=<SqueezeBackward1>)  len= 423
# Meeting= Meeting 57  Query= 1   Predicted spans:  tensor([128.7861, 182.9585], grad_fn=<SqueezeBackward1>)  len= 423
# Meeting= Meeting 57  Query= 2   Predicted spans:  tensor([125.4299, 178.8047], grad_fn=<SqueezeBackward1>)  len= 423
# Meeting= Meeting 57  Query= 3   Predicted spans:  tensor([131.1623, 188.0828], grad_fn=<SqueezeBackward1>)  len= 423
# Meeting= Meeting 57  Query= 4   Predicted spans:  tensor([132.2751, 188.8304], grad_fn=<SqueezeBackward1>)  len= 423
# Meeting= Meeting 57  Query= 5   Predicted spans:  tensor([132.2006, 188.6915], grad_fn=<SqueezeBackward1>)  len= 423
#
# Meeting= Meeting 58  Query= 0   Predicted spans:  tensor([133.2938, 177.3370], grad_fn=<SqueezeBackward1>)  len= 181
# Meeting= Meeting 58  Query= 1   Predicted spans:  tensor([134.3673, 178.6132], grad_fn=<SqueezeBackward1>)  len= 181
# Meeting= Meeting 58  Query= 2   Predicted spans:  tensor([134.2275, 178.4124], grad_fn=<SqueezeBackward1>)  len= 181
# Meeting= Meeting 58  Query= 3   Predicted spans:  tensor([134.6198, 178.8524], grad_fn=<SqueezeBackward1>)  len= 181
# Meeting= Meeting 58  Query= 4   Predicted spans:  tensor([134.1511, 177.8918], grad_fn=<SqueezeBackward1>)  len= 181
# Meeting= Meeting 58  Query= 5   Predicted spans:  tensor([134.0216, 177.9296], grad_fn=<SqueezeBackward1>)  len= 181
#
# Meeting= Meeting 59  Query= 0   Predicted spans:  tensor([135.7584, 178.2277], grad_fn=<SqueezeBackward1>)  len= 129
# Meeting= Meeting 59  Query= 1   Predicted spans:  tensor([136.5099, 177.4085], grad_fn=<SqueezeBackward1>)  len= 129
# Meeting= Meeting 59  Query= 2   Predicted spans:  tensor([137.0739, 177.3843], grad_fn=<SqueezeBackward1>)  len= 129
# Meeting= Meeting 59  Query= 3   Predicted spans:  tensor([136.3332, 177.1455], grad_fn=<SqueezeBackward1>)  len= 129
# Meeting= Meeting 59  Query= 4   Predicted spans:  tensor([135.9482, 176.6266], grad_fn=<SqueezeBackward1>)  len= 129
# Meeting= Meeting 59  Query= 5   Predicted spans:  tensor([136.5913, 177.5475], grad_fn=<SqueezeBackward1>)  len= 129
#
# Meeting= Meeting 60  Query= 0   Predicted spans:  tensor([134.1325, 179.3290], grad_fn=<SqueezeBackward1>)  len= 215
# Meeting= Meeting 60  Query= 1   Predicted spans:  tensor([132.9629, 177.0529], grad_fn=<SqueezeBackward1>)  len= 215
# Meeting= Meeting 60  Query= 2   Predicted spans:  tensor([135.5499, 180.1791], grad_fn=<SqueezeBackward1>)  len= 215
# Meeting= Meeting 60  Query= 3   Predicted spans:  tensor([134.1936, 179.0533], grad_fn=<SqueezeBackward1>)  len= 215
# Meeting= Meeting 60  Query= 4   Predicted spans:  tensor([134.0676, 178.3410], grad_fn=<SqueezeBackward1>)  len= 215
# Meeting= Meeting 60  Query= 5   Predicted spans:  tensor([132.5996, 175.7925], grad_fn=<SqueezeBackward1>)  len= 215
#
# Meeting= Meeting 61  Query= 0   Predicted spans:  tensor([138.0096, 195.2647], grad_fn=<SqueezeBackward1>)  len= 406
# Meeting= Meeting 61  Query= 1   Predicted spans:  tensor([139.4721, 195.5192], grad_fn=<SqueezeBackward1>)  len= 406
# Meeting= Meeting 61  Query= 2   Predicted spans:  tensor([139.1167, 195.7089], grad_fn=<SqueezeBackward1>)  len= 406
# Meeting= Meeting 61  Query= 3   Predicted spans:  tensor([138.8132, 194.6935], grad_fn=<SqueezeBackward1>)  len= 406
# Meeting= Meeting 61  Query= 4   Predicted spans:  tensor([139.4715, 195.2135], grad_fn=<SqueezeBackward1>)  len= 406
# Meeting= Meeting 61  Query= 5   Predicted spans:  tensor([140.8800, 196.0785], grad_fn=<SqueezeBackward1>)  len= 406
#
# Meeting= Meeting 62  Query= 0   Predicted spans:  tensor([139.9733, 179.5760], grad_fn=<SqueezeBackward1>)  len= 103
# Meeting= Meeting 62  Query= 1   Predicted spans:  tensor([140.7775, 180.9668], grad_fn=<SqueezeBackward1>)  len= 103
# Meeting= Meeting 62  Query= 2   Predicted spans:  tensor([139.8833, 179.7796], grad_fn=<SqueezeBackward1>)  len= 103
# Meeting= Meeting 62  Query= 3   Predicted spans:  tensor([140.3784, 180.8906], grad_fn=<SqueezeBackward1>)  len= 103
# Meeting= Meeting 62  Query= 4   Predicted spans:  tensor([140.0781, 179.9690], grad_fn=<SqueezeBackward1>)  len= 103
# Meeting= Meeting 62  Query= 5   Predicted spans:  tensor([139.8179, 180.1801], grad_fn=<SqueezeBackward1>)  len= 103
# Meeting= Meeting 62  Query= 6   Predicted spans:  tensor([138.0672, 179.7934], grad_fn=<SqueezeBackward1>)  len= 103
#
# Meeting= Meeting 63  Query= 0   Predicted spans:  tensor([137.8668, 178.9158], grad_fn=<SqueezeBackward1>)  len= 109
# ...
# Meeting= Meeting 145  Query= 1   Predicted spans:  tensor([190.9808, 265.0452], grad_fn=<SqueezeBackward1>)  len= 479
# Meeting= Meeting 145  Query= 2   Predicted spans:  tensor([184.6255, 273.1216], grad_fn=<SqueezeBackward1>)  len= 479
# Meeting= Meeting 145  Query= 3   Predicted spans:  tensor([175.1811, 270.6454], grad_fn=<SqueezeBackward1>)  len= 479
# Meeting= Meeting 145  Query= 4   Predicted spans:  tensor([187.1563, 271.9892], grad_fn=<SqueezeBackward1>)  len= 479
# Meeting= Meeting 145  Query= 5   Predicted spans:  tensor([180.9330, 266.8490], grad_fn=<SqueezeBackward1>)  len= 479
#
# Meeting= Meeting 146  Query= 0   Predicted spans:  tensor([47.1317, 60.8108], grad_fn=<SqueezeBackward1>)  len= 124
# Meeting= Meeting 146  Query= 1   Predicted spans:  tensor([56.8965, 68.5457], grad_fn=<SqueezeBackward1>)  len= 124
# Meeting= Meeting 146  Query= 2   Predicted spans:  tensor([52.1555, 56.8030], grad_fn=<SqueezeBackward1>)  len= 124
# Meeting= Meeting 146  Query= 3   Predicted spans:  tensor([56.5450, 71.7927], grad_fn=<SqueezeBackward1>)  len= 124
# Meeting= Meeting 146  Query= 4   Predicted spans:  tensor([52.4836, 80.1449], grad_fn=<SqueezeBackward1>)  len= 124
# Meeting= Meeting 146  Query= 5   Predicted spans:  tensor([52.1875, 61.1016], grad_fn=<SqueezeBackward1>)  len= 124
# Meeting= Meeting 146  Query= 6   Predicted spans:  tensor([48.3037, 60.9587], grad_fn=<SqueezeBackward1>)  len= 124
# Meeting= Meeting 146  Query= 7   Predicted spans:  tensor([56.7399, 69.1762], grad_fn=<SqueezeBackward1>)  len= 124
# Meeting= Meeting 146  Query= 8   Predicted spans:  tensor([63.7613, 78.1615], grad_fn=<SqueezeBackward1>)  len= 124
# Meeting= Meeting 146  Query= 9   Predicted spans:  tensor([58.8825, 63.9527], grad_fn=<SqueezeBackward1>)  len= 124
# Meeting= Meeting 146  Query= 10   Predicted spans:  tensor([53.3383, 60.0185], grad_fn=<SqueezeBackward1>)  len= 124
#
# Meeting= Meeting 147  Query= 0   Predicted spans:  tensor([145.7173, 208.8040], grad_fn=<SqueezeBackward1>)  len= 166
# Meeting= Meeting 147  Query= 1   Predicted spans:  tensor([146.9682, 200.8165], grad_fn=<SqueezeBackward1>)  len= 166
# Meeting= Meeting 147  Query= 2   Predicted spans:  tensor([150.9482, 220.4475], grad_fn=<SqueezeBackward1>)  len= 166
# Meeting= Meeting 147  Query= 3   Predicted spans:  tensor([151.9047, 217.8011], grad_fn=<SqueezeBackward1>)  len= 166
# Meeting= Meeting 147  Query= 4   Predicted spans:  tensor([151.4043, 238.4645], grad_fn=<SqueezeBackward1>)  len= 166
# Meeting= Meeting 147  Query= 5   Predicted spans:  tensor([151.2641, 226.0838], grad_fn=<SqueezeBackward1>)  len= 166
#
# Meeting= Meeting 148  Query= 0   Predicted spans:  tensor([187.2714, 292.4512], grad_fn=<SqueezeBackward1>)  len= 516
# Meeting= Meeting 148  Query= 1   Predicted spans:  tensor([202.1171, 270.6739], grad_fn=<SqueezeBackward1>)  len= 516
# Meeting= Meeting 148  Query= 2   Predicted spans:  tensor([203.3308, 270.1223], grad_fn=<SqueezeBackward1>)  len= 516
# Meeting= Meeting 148  Query= 3   Predicted spans:  tensor([188.4409, 299.1783], grad_fn=<SqueezeBackward1>)  len= 516
# Meeting= Meeting 148  Query= 4   Predicted spans:  tensor([211.0165, 302.1714], grad_fn=<SqueezeBackward1>)  len= 516
#
# Meeting= Meeting 149  Query= 0   Predicted spans:  tensor([158.1437, 242.6770], grad_fn=<SqueezeBackward1>)  len= 166
# Meeting= Meeting 149  Query= 1   Predicted spans:  tensor([169.2958, 241.7702], grad_fn=<SqueezeBackward1>)  len= 166
# Meeting= Meeting 149  Query= 2   Predicted spans:  tensor([168.3209, 253.4837], grad_fn=<SqueezeBackward1>)  len= 166
# Meeting= Meeting 149  Query= 3   Predicted spans:  tensor([164.6426, 236.9215], grad_fn=<SqueezeBackward1>)  len= 166
# Meeting= Meeting 149  Query= 4   Predicted spans:  tensor([166.7420, 247.1516], grad_fn=<SqueezeBackward1>)  len= 166
# Meeting= Meeting 149  Query= 5   Predicted spans:  tensor([167.8827, 250.2645], grad_fn=<SqueezeBackward1>)  len= 166
#
# Meeting= Meeting 150  Query= 0   Predicted spans:  tensor([192.3169, 292.5388], grad_fn=<SqueezeBackward1>)  len= 438
# Meeting= Meeting 150  Query= 1   Predicted spans:  tensor([201.4572, 298.3121], grad_fn=<SqueezeBackward1>)  len= 438
# Meeting= Meeting 150  Query= 2   Predicted spans:  tensor([196.8485, 290.1825], grad_fn=<SqueezeBackward1>)  len= 438
# Meeting= Meeting 150  Query= 3   Predicted spans:  tensor([200.9977, 296.3935], grad_fn=<SqueezeBackward1>)  len= 438
# Meeting= Meeting 150  Query= 4   Predicted spans:  tensor([201.3877, 292.2934], grad_fn=<SqueezeBackward1>)  len= 438
# Meeting= Meeting 150  Query= 5   Predicted spans:  tensor([198.9868, 273.4288], grad_fn=<SqueezeBackward1>)  len= 438
#
# Meeting= Meeting 151  Query= 0   Predicted spans:  tensor([48.6975, 60.8737], grad_fn=<SqueezeBackward1>)  len= 86
# Meeting= Meeting 151  Query= 1   Predicted spans:  tensor([57.0655, 51.4936], grad_fn=<SqueezeBackward1>)  len= 86
# Meeting= Meeting 151  Query= 2   Predicted spans:  tensor([51.9097, 50.6077], grad_fn=<SqueezeBackward1>)  len= 86
# Meeting= Meeting 151  Query= 3   Predicted spans:  tensor([39.2236, 50.7993], grad_fn=<SqueezeBackward1>)  len= 86
# Meeting= Meeting 151  Query= 4   Predicted spans:  tensor([55.7545, 61.7308], grad_fn=<SqueezeBackward1>)  len= 86
# Meeting= Meeting 151  Query= 5   Predicted spans:  tensor([52.4406, 45.0010], grad_fn=<SqueezeBackward1>)  len= 86
# Meeting= Meeting 151  Query= 6   Predicted spans:  tensor([51.2560, 63.0002], grad_fn=<SqueezeBackward1>)  len= 86
# Meeting= Meeting 151  Query= 7   Predicted spans:  tensor([53.8668, 53.4625], grad_fn=<SqueezeBackward1>)  len= 86
# Meeting= Meeting 151  Query= 8   Predicted spans:  tensor([53.4372, 40.9404], grad_fn=<SqueezeBackward1>)  len= 86
# Meeting= Meeting 151  Query= 9   Predicted spans:  tensor([44.0352, 57.3765], grad_fn=<SqueezeBackward1>)  len= 86
# Meeting= Meeting 151  Query= 10   Predicted spans:  tensor([55.6371, 66.2570], grad_fn=<SqueezeBackward1>)  len= 86
# Meeting= Meeting 151  Query= 11   Predicted spans:  tensor([48.3905, 38.1456], grad_fn=<SqueezeBackward1>)  len= 86
#
# Meeting= Meeting 152  Query= 0   Predicted spans:  tensor([159.3391, 238.6278], grad_fn=<SqueezeBackward1>)  len= 284
# Meeting= Meeting 152  Query= 1   Predicted spans:  tensor([170.5344, 229.7944], grad_fn=<SqueezeBackward1>)  len= 284
# Meeting= Meeting 152  Query= 2   Predicted spans:  tensor([165.7368, 218.8416], grad_fn=<SqueezeBackward1>)  len= 284
# Meeting= Meeting 152  Query= 3   Predicted spans:  tensor([158.6993, 235.2079], grad_fn=<SqueezeBackward1>)  len= 284
# Meeting= Meeting 152  Query= 4   Predicted spans:  tensor([171.8818, 230.6667], grad_fn=<SqueezeBackward1>)  len= 284
# Meeting= Meeting 152  Query= 5   Predicted spans:  tensor([167.8729, 226.6290], grad_fn=<SqueezeBackward1>)  len= 284
# Meeting= Meeting 152  Query= 6   Predicted spans:  tensor([155.6303, 236.4056], grad_fn=<SqueezeBackward1>)  len= 284
#
# Meeting= Meeting 153  Query= 0   Predicted spans:  tensor([168.7430, 218.1487], grad_fn=<SqueezeBackward1>)  len= 169
# Meeting= Meeting 153  Query= 1   Predicted spans:  tensor([169.2300, 224.9500], grad_fn=<SqueezeBackward1>)  len= 169
# Meeting= Meeting 153  Query= 2   Predicted spans:  tensor([171.5317, 236.2252], grad_fn=<SqueezeBackward1>)  len= 169
# Meeting= Meeting 153  Query= 3   Predicted spans:  tensor([170.7171, 225.2339], grad_fn=<SqueezeBackward1>)  len= 169
# Meeting= Meeting 153  Query= 4   Predicted spans:  tensor([155.2852, 222.5495], grad_fn=<SqueezeBackward1>)  len= 169
# Meeting= Meeting 153  Query= 5   Predicted spans:  tensor([160.4029, 240.9447], grad_fn=<SqueezeBackward1>)  len= 169
#
# Meeting= Meeting 154  Query= 0   Predicted spans:  tensor([148.9685, 208.0975], grad_fn=<SqueezeBackward1>)  len= 64
# Meeting= Meeting 154  Query= 1   Predicted spans:  tensor([155.3481, 209.1147], grad_fn=<SqueezeBackward1>)  len= 64
# Meeting= Meeting 154  Query= 2   Predicted spans:  tensor([145.1532, 186.2294], grad_fn=<SqueezeBackward1>)  len= 64
# Meeting= Meeting 154  Query= 3   Predicted spans:  tensor([144.7150, 201.9214], grad_fn=<SqueezeBackward1>)  len= 64
# Meeting= Meeting 154  Query= 4   Predicted spans:  tensor([149.5832, 187.8537], grad_fn=<SqueezeBackward1>)  len= 64
# Meeting= Meeting 154  Query= 5   Predicted spans:  tensor([154.5528, 211.3153], grad_fn=<SqueezeBackward1>)  len= 64
#
# Meeting= Meeting 155  Query= 0   Predicted spans:  tensor([143.5632, 206.9156], grad_fn=<SqueezeBackward1>)  len= 189
# Meeting= Meeting 155  Query= 1   Predicted spans:  tensor([159.9044, 206.8925], grad_fn=<SqueezeBackward1>)  len= 189
# Meeting= Meeting 155  Query= 2   Predicted spans:  tensor([156.9312, 228.1597], grad_fn=<SqueezeBackward1>)  len= 189
# Meeting= Meeting 155  Query= 3   Predicted spans:  tensor([162.6752, 203.1652], grad_fn=<SqueezeBackward1>)  len= 189
# Meeting= Meeting 155  Query= 4   Predicted spans:  tensor([159.7300, 204.8865], grad_fn=<SqueezeBackward1>)  len= 189
# Meeting= Meeting 155  Query= 5   Predicted spans:  tensor([144.5168, 211.8040], grad_fn=<SqueezeBackward1>)  len= 189
# Meeting= Meeting 155  Query= 6   Predicted spans:  tensor([149.2846, 209.7546], grad_fn=<SqueezeBackward1>)  len= 189
#
# Meeting= Meeting 156  Query= 0   Predicted spans:  tensor([73.2698, 62.3487], grad_fn=<SqueezeBackward1>)  len= 330
# Meeting= Meeting 156  Query= 1   Predicted spans:  tensor([93.2054, 97.2419], grad_fn=<SqueezeBackward1>)  len= 330
# Meeting= Meeting 156  Query= 2   Predicted spans:  tensor([79.7663, 82.8089], grad_fn=<SqueezeBackward1>)  len= 330
# Meeting= Meeting 156  Query= 3   Predicted spans:  tensor([ 93.7950, 100.0178], grad_fn=<SqueezeBackward1>)  len= 330
# Meeting= Meeting 156  Query= 4   Predicted spans:  tensor([80.8906, 98.9467], grad_fn=<SqueezeBackward1>)  len= 330
# Meeting= Meeting 156  Query= 5   Predicted spans:  tensor([ 92.6563, 103.6732], grad_fn=<SqueezeBackward1>)  len= 330
#
# Meeting= Meeting 157  Query= 0   Predicted spans:  tensor([105.8038, 144.4594], grad_fn=<SqueezeBackward1>)  len= 120
# Meeting= Meeting 157  Query= 1   Predicted spans:  tensor([119.2653, 134.3071], grad_fn=<SqueezeBackward1>)  len= 120
# Meeting= Meeting 157  Query= 2   Predicted spans:  tensor([113.8376, 132.4060], grad_fn=<SqueezeBackward1>)  len= 120
# Meeting= Meeting 157  Query= 3   Predicted spans:  tensor([108.6803, 148.5293], grad_fn=<SqueezeBackward1>)  len= 120
# Meeting= Meeting 157  Query= 4   Predicted spans:  tensor([115.1844, 137.2186], grad_fn=<SqueezeBackward1>)  len= 120
# Meeting= Meeting 157  Query= 5   Predicted spans:  tensor([116.1027, 136.9987], grad_fn=<SqueezeBackward1>)  len= 120
#
# Meeting= Meeting 158  Query= 0   Predicted spans:  tensor([73.4299, 86.6232], grad_fn=<SqueezeBackward1>)  len= 311
# Meeting= Meeting 158  Query= 1   Predicted spans:  tensor([84.6458, 89.8183], grad_fn=<SqueezeBackward1>)  len= 311
# Meeting= Meeting 158  Query= 2   Predicted spans:  tensor([84.9937, 81.8667], grad_fn=<SqueezeBackward1>)  len= 311
# Meeting= Meeting 158  Query= 3   Predicted spans:  tensor([70.6580, 91.7030], grad_fn=<SqueezeBackward1>)  len= 311
# Meeting= Meeting 158  Query= 4   Predicted spans:  tensor([77.5834, 90.0866], grad_fn=<SqueezeBackward1>)  len= 311
# Meeting= Meeting 158  Query= 5   Predicted spans:  tensor([83.3466, 84.6808], grad_fn=<SqueezeBackward1>)  len= 311
# Meeting= Meeting 158  Query= 6   Predicted spans:  tensor([70.7313, 87.5132], grad_fn=<SqueezeBackward1>)  len= 311
# Meeting= Meeting 158  Query= 7   Predicted spans:  tensor([75.0076, 80.6554], grad_fn=<SqueezeBackward1>)  len= 311
# Meeting= Meeting 158  Query= 8   Predicted spans:  tensor([82.5990, 86.8398], grad_fn=<SqueezeBackward1>)  len= 311
# Meeting= Meeting 158  Query= 9   Predicted spans:  tensor([ 66.1509, 103.3317], grad_fn=<SqueezeBackward1>)  len= 311
# Meeting= Meeting 158  Query= 10   Predicted spans:  tensor([79.2007, 95.7611], grad_fn=<SqueezeBackward1>)  len= 311
# Meeting= Meeting 158  Query= 11   Predicted spans:  tensor([82.8237, 98.3063], grad_fn=<SqueezeBackward1>)  len= 311
#
# Meeting= Meeting 159  Query= 0   Predicted spans:  tensor([144.8399, 223.1517], grad_fn=<SqueezeBackward1>)  len= 274
# Meeting= Meeting 159  Query= 1   Predicted spans:  tensor([153.6131, 213.7981], grad_fn=<SqueezeBackward1>)  len= 274
# Meeting= Meeting 159  Query= 2   Predicted spans:  tensor([156.3107, 225.5292], grad_fn=<SqueezeBackward1>)  len= 274
# Meeting= Meeting 159  Query= 3   Predicted spans:  tensor([147.5474, 222.0448], grad_fn=<SqueezeBackward1>)  len= 274
# Meeting= Meeting 159  Query= 4   Predicted spans:  tensor([155.6185, 209.5565], grad_fn=<SqueezeBackward1>)  len= 274
# Meeting= Meeting 159  Query= 5   Predicted spans:  tensor([149.6628, 207.0628], grad_fn=<SqueezeBackward1>)  len= 274
#
# Meeting= Meeting 160  Query= 0   Predicted spans:  tensor([48.1472, 63.6253], grad_fn=<SqueezeBackward1>)  len= 136
# Meeting= Meeting 160  Query= 1   Predicted spans:  tensor([59.6735, 66.3943], grad_fn=<SqueezeBackward1>)  len= 136
# Meeting= Meeting 160  Query= 2   Predicted spans:  tensor([53.6495, 70.1336], grad_fn=<SqueezeBackward1>)  len= 136
# Meeting= Meeting 160  Query= 3   Predicted spans:  tensor([55.1458, 52.5568], grad_fn=<SqueezeBackward1>)  len= 136
# Meeting= Meeting 160  Query= 4   Predicted spans:  tensor([51.7300, 71.3899], grad_fn=<SqueezeBackward1>)  len= 136
# Meeting= Meeting 160  Query= 5   Predicted spans:  tensor([53.4285, 62.2282], grad_fn=<SqueezeBackward1>)  len= 136
# Meeting= Meeting 160  Query= 6   Predicted spans:  tensor([67.8334, 76.8820], grad_fn=<SqueezeBackward1>)  len= 136
# Meeting= Meeting 160  Query= 7   Predicted spans:  tensor([68.8640, 79.5559], grad_fn=<SqueezeBackward1>)  len= 136
# Meeting= Meeting 160  Query= 8   Predicted spans:  tensor([47.8403, 61.6835], grad_fn=<SqueezeBackward1>)  len= 136
# Meeting= Meeting 160  Query= 9   Predicted spans:  tensor([52.8959, 58.6570], grad_fn=<SqueezeBackward1>)  len= 136
# Meeting= Meeting 160  Query= 10   Predicted spans:  tensor([53.2073, 50.7284], grad_fn=<SqueezeBackward1>)  len= 136
# Meeting= Meeting 160  Query= 11   Predicted spans:  tensor([55.0386, 58.1788], grad_fn=<SqueezeBackward1>)  len= 136
# Meeting= Meeting 160  Query= 12   Predicted spans:  tensor([52.4835, 79.9303], grad_fn=<SqueezeBackward1>)  len= 136
# Meeting= Meeting 160  Query= 13   Predicted spans:  tensor([57.7672, 63.7676], grad_fn=<SqueezeBackward1>)  len= 136
# Meeting= Meeting 160  Query= 14   Predicted spans:  tensor([61.6892, 76.5071], grad_fn=<SqueezeBackward1>)  len= 136
# Meeting= Meeting 160  Query= 15   Predicted spans:  tensor([64.4856, 80.0853], grad_fn=<SqueezeBackward1>)  len= 136
#
# Meeting= Meeting 161  Query= 0   Predicted spans:  tensor([ 82.2775, 113.3996], grad_fn=<SqueezeBackward1>)  len= 304
# Meeting= Meeting 161  Query= 1   Predicted spans:  tensor([ 84.8782, 101.3320], grad_fn=<SqueezeBackward1>)  len= 304
# Meeting= Meeting 161  Query= 2   Predicted spans:  tensor([ 86.8789, 102.8953], grad_fn=<SqueezeBackward1>)  len= 304
# Meeting= Meeting 161  Query= 3   Predicted spans:  tensor([ 83.9793, 115.9287], grad_fn=<SqueezeBackward1>)  len= 304
# Meeting= Meeting 161  Query= 4   Predicted spans:  tensor([ 91.3925, 123.0606], grad_fn=<SqueezeBackward1>)  len= 304
# Meeting= Meeting 161  Query= 5   Predicted spans:  tensor([ 90.1655, 108.8796], grad_fn=<SqueezeBackward1>)  len= 304
# Meeting= Meeting 161  Query= 6   Predicted spans:  tensor([ 88.1200, 128.0916], grad_fn=<SqueezeBackward1>)  len= 304
# Meeting= Meeting 161  Query= 7   Predicted spans:  tensor([ 92.5159, 119.1522], grad_fn=<SqueezeBackward1>)  len= 304
# Meeting= Meeting 161  Query= 8   Predicted spans:  tensor([ 92.5030, 113.1762], grad_fn=<SqueezeBackward1>)  len= 304
# Meeting= Meeting 161  Query= 9   Predicted spans:  tensor([ 86.2587, 120.9439], grad_fn=<SqueezeBackward1>)  len= 304
# Meeting= Meeting 161  Query= 10   Predicted spans:  tensor([ 94.4160, 115.4247], grad_fn=<SqueezeBackward1>)  len= 304
# Meeting= Meeting 161  Query= 11   Predicted spans:  tensor([100.2701, 123.0051], grad_fn=<SqueezeBackward1>)  len= 304
# 100%|██████████| 10/10 [36:36<00:00, 219.61s/it]
#
#  Epoch [10/10], Loss: 30.81246344248454
# ======================================================

# %%
# Evaluate the performance of Locater

# %%
# Save the Locater
torch.save(locater, corpus_root_DS+'locater(ELECTRA).pth')

# %% [markdown]
# ### Evaluate the Locator

# %%
locater = torch.load(corpus_root_DS+'locater(RoBERTa).pth')

# %%
# Evaluate the performance of Locater (with train set)

cos_sim_value = []
manhattan_dis = []
minkowski_dis = []

for meeting_num, meeting in new_tensor_dict.items():  # iterate meeting
   # Get training data for one meeting
    transcript_emb = meeting['Transcript']
    query_set = meeting['Query']
    start_end_label = meeting['Spans'] #label
    meeting_len = meeting['Length'] # meeting length

    for i, (inputs_query, label) in enumerate(zip(query_set, start_end_label)):  # iterate query for a meeting

      transcript_emb = transcript_emb.to('cpu')
      inputs_query = inputs_query.to('cpu')
      label = label.to('cpu')

      predicted_span = locater(transcript_emb, inputs_query, meeting_len)

      # Cosine similarity
      cos_sim = F.cosine_similarity(predicted_span, label)

      # Manhattan Distance
      manhattan_distance = torch.sum(torch.abs(predicted_span - label))

      # Minkowski Distance (p=1.5)
      minkowski_distance = F.pairwise_distance(predicted_span.unsqueeze(0), label.unsqueeze(0), p=1.5)

      print('Meeting ', meeting_num, 'Query ', i, 'len=', meeting_len)
      print('predicted_span=', predicted_span)
      print('')
      print('cos_sim=', cos_sim)
      print('Manhattan dis=', manhattan_distance)
      print('Minkowski dis=', minkowski_distance)
      print('')

      cos_sim_value.append(cos_sim) # cos_sim of all predicted_value & true value
      manhattan_dis.append(manhattan_distance) # manhattan of all predicted_value & true value
      minkowski_dis.append(minkowski_distance) # minkowski of all predicted_value & true value
  
    print('==============================')

print('Average cosine similarity for prediction =', (sum(cos_sim_value)/len(cos_sim_value)))
print('Average Manhattan distance for prediction =', (sum(manhattan_dis)/len(manhattan_dis)))
print('Average Minkowski distance for prediction =', (sum(minkowski_distance)/len(minkowski_distance)))

# %%
# Evaluate the performance of Locater (with validation set)

cos_sim_value = []
manhattan_dis = []
minkowski_dis = []
euclid_dis = []

for meeting_num, meeting in new_tensor_dict.items():  # iterate meeting
   # Get training data for one meeting
    transcript_emb = meeting['Meeting 0']['Transcript']
    query_set = meeting['Meeting 0']['Query']
    start_end_label = meeting['Meeting 0']['Spans'] #label
    meeting_len = meeting['Meeting 0']['Length'] # meeting length

    for i, (inputs_query, label) in enumerate(zip(query_set, start_end_label)):  # iterate query for a meeting

      transcript_emb = transcript_emb.to('cpu')
      inputs_query = inputs_query.to('cpu')
      label = label.to('cpu')

      predicted_span = locater(transcript_emb, inputs_query, meeting_len)

      # Cosine similarity
      cos_sim = F.cosine_similarity(predicted_span, label)

      # Manhattan Distance
      manhattan_distance = torch.sum(torch.abs(predicted_span - label))

      # Minkowski Distance (p=1.5)
      minkowski_distance = F.pairwise_distance(predicted_span.unsqueeze(0), label.unsqueeze(0), p=1.5)

      # Euclid Distance
      euclid = torch.sqrt(torch.sum((predicted_span - label) ** 2, dim=1))

      print('Meeting ', meeting_num, 'Query ', i, 'len=', meeting_len)
      print('predicted_span=', predicted_span, 'gold_span=', label)
      print('Euclid distance=', euclid)
      print('cos_sim=', cos_sim)
      print('Manhattan dis=', manhattan_distance)
      print('Minkowski dis=', minkowski_distance)
      print('')

      euclid_dis.append(euclid)  # Euclid of all predicted_value & true value
      cos_sim_value.append(cos_sim) # cos_sim of all predicted_value & true value
      manhattan_dis.append(manhattan_distance) # manhattan of all predicted_value & true value
      minkowski_dis.append(minkowski_distance) # minkowski of all predicted_value & true value
  
    print('==============================')

print('Average Euclid Distance for prediction =', (sum(euclid_dis)/len(euclid_dis)))
print('Average cosine similarity for prediction =', (sum(cos_sim_value)/len(cos_sim_value)))
print('Average Manhattan distance for prediction =', (sum(manhattan_dis)/len(manhattan_dis)))
print('Average Minkowski distance for prediction =', (sum(minkowski_distance)/len(minkowski_distance)))
# Out:
# Meeting  meeting: ES2011b.json Query  0 len= 361
# predicted_span= tensor([[217.3151, 280.9408]], grad_fn=<AbsBackward0>) gold_span= tensor([ 1., 52.], requires_grad=True)
# Euclid distance= tensor([314.9701], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.8026], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(445.2560, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[353.4710]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2011b.json Query  1 len= 361
# predicted_span= tensor([[213.4664, 275.1346]], grad_fn=<AbsBackward0>) gold_span= tensor([73., 88.], requires_grad=True)
# Euclid distance= tensor([233.9875], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9995], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(327.6010, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[261.3363]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2011b.json Query  2 len= 361
# predicted_span= tensor([[215.0727, 269.6426]], grad_fn=<AbsBackward0>) gold_span= tensor([ 89., 120.], requires_grad=True)
# Euclid distance= tensor([195.6712], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9994], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(275.7153, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[219.2352]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2011b.json Query  3 len= 361
# predicted_span= tensor([[186.2049, 275.7439]], grad_fn=<AbsBackward0>) gold_span= tensor([176., 205.], requires_grad=True)
# Euclid distance= tensor([71.4761], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9933], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(80.9488, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[73.3048]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: Bed008.json Query  0 len= 724
# predicted_span= tensor([[241.1367, 321.2390]], grad_fn=<AbsBackward0>) gold_span= tensor([45., 81.], requires_grad=True)
# Euclid distance= tensor([310.1360], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9907], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(436.3757, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[347.2361]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bed008.json Query  1 len= 724
# predicted_span= tensor([[262.4305, 313.9645]], grad_fn=<AbsBackward0>) gold_span= tensor([47., 81.], requires_grad=True)
# Euclid distance= tensor([317.3055], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9855], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(448.3951, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[356.0275]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bed008.json Query  2 len= 724
# predicted_span= tensor([[235.8503, 313.0483]], grad_fn=<AbsBackward0>) gold_span= tensor([433., 533.], requires_grad=True)
# Euclid distance= tensor([295.3756], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9993], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(417.1014, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[331.3010]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bed008.json Query  3 len= 724
# predicted_span= tensor([[256.8395, 302.6016]], grad_fn=<AbsBackward0>) gold_span= tensor([433., 533.], requires_grad=True)
# Euclid distance= tensor([290.0275], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9998], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(406.5589, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[324.1218]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bed008.json Query  4 len= 724
# predicted_span= tensor([[246.9759, 341.8258]], grad_fn=<AbsBackward0>) gold_span= tensor([669., 749.], requires_grad=True)
# Euclid distance= tensor([586.4258], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9947], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(829.1983, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[658.1880]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bed008.json Query  5 len= 724
# predicted_span= tensor([[249.8113, 306.2174]], grad_fn=<AbsBackward0>) gold_span= tensor([727., 749.], requires_grad=True)
# Euclid distance= tensor([650.9727], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9963], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(919.9712, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[730.4371]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: IS1003b.json Query  0 len= 393
# predicted_span= tensor([[184.2289, 273.2763]], grad_fn=<AbsBackward0>) gold_span= tensor([43., 97.], requires_grad=True)
# Euclid distance= tensor([225.8737], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9846], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(317.5052, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[252.7717]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: IS1003b.json Query  1 len= 393
# predicted_span= tensor([[210.8952, 265.0648]], grad_fn=<AbsBackward0>) gold_span= tensor([47., 80.], requires_grad=True)
# Euclid distance= tensor([247.2056], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9901], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(348.9601, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[277.2247]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: IS1003b.json Query  2 len= 393
# predicted_span= tensor([[183.3097, 268.4547]], grad_fn=<AbsBackward0>) gold_span= tensor([338., 361.], requires_grad=True)
# Euclid distance= tensor([180.2601], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9883], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(247.2356, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[199.3308]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: IS1003b.json Query  3 len= 393
# predicted_span= tensor([[186.2937, 263.7503]], grad_fn=<AbsBackward0>) gold_span= tensor([ 98., 193.], requires_grad=True)
# Euclid distance= tensor([113.1432], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9895], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(159.0440, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[126.6173]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: IS1003b.json Query  4 len= 393
# predicted_span= tensor([[208.4336, 249.6162]], grad_fn=<AbsBackward0>) gold_span= tensor([141., 190.], requires_grad=True)
# Euclid distance= tensor([90.0077], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9984], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(127.0498, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[100.9350]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: IS1003b.json Query  5 len= 393
# predicted_span= tensor([[214.0987, 260.9877]], grad_fn=<AbsBackward0>) gold_span= tensor([227., 251.], requires_grad=True)
# Euclid distance= tensor([16.3156], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9988], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(22.8890, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[18.2406]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: IS1003b.json Query  6 len= 393
# predicted_span= tensor([[186.7026, 271.4164]], grad_fn=<AbsBackward0>) gold_span= tensor([199., 207.], requires_grad=True)
# Euclid distance= tensor([65.5798], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9867], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(76.7138, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[67.9504]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: IS1003b.json Query  7 len= 393
# predicted_span= tensor([[199.3035, 245.1316]], grad_fn=<AbsBackward0>) gold_span= tensor([260., 278.], requires_grad=True)
# Euclid distance= tensor([69.0246], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9976], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(93.5649, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[75.9051]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: IS1003b.json Query  8 len= 393
# predicted_span= tensor([[185.3735, 261.3221]], grad_fn=<AbsBackward0>) gold_span= tensor([264., 283.], requires_grad=True)
# Euclid distance= tensor([81.5602], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9911], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(100.3044, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[86.0427]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: ES2011d.json Query  0 len= 582
# predicted_span= tensor([[224.5013, 302.7315]], grad_fn=<AbsBackward0>) gold_span= tensor([  1., 238.], requires_grad=True)
# Euclid distance= tensor([232.6864], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.8057], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(288.2328, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[246.1606]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2011d.json Query  1 len= 582
# predicted_span= tensor([[222.2890, 299.4953]], grad_fn=<AbsBackward0>) gold_span= tensor([239., 398.], requires_grad=True)
# Euclid distance= tensor([99.9121], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9952], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(115.2157, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[103.0415]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2011d.json Query  2 len= 582
# predicted_span= tensor([[224.6734, 306.4201]], grad_fn=<AbsBackward0>) gold_span= tensor([399., 598.], requires_grad=True)
# Euclid distance= tensor([339.7184], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9990], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(465.9065, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[375.6461]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2011d.json Query  3 len= 582
# predicted_span= tensor([[232.8598, 278.9787]], grad_fn=<AbsBackward0>) gold_span= tensor([239., 398.], requires_grad=True)
# Euclid distance= tensor([119.1796], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9881], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(125.1615, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[119.9493]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2011d.json Query  4 len= 582
# predicted_span= tensor([[244.9255, 293.1003]], grad_fn=<AbsBackward0>) gold_span= tensor([414., 434.], requires_grad=True)
# Euclid distance= tensor([220.0884], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9978], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(309.9742, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[246.5349]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2011d.json Query  5 len= 582
# predicted_span= tensor([[244.9740, 296.1796]], grad_fn=<AbsBackward0>) gold_span= tensor([435., 480.], requires_grad=True)
# Euclid distance= tensor([264.3857], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9990], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(373.8463, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[296.7426]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: ES2004c.json Query  0 len= 560
# predicted_span= tensor([[231.1720, 274.5651]], grad_fn=<AbsBackward0>) gold_span= tensor([23., 29.], requires_grad=True)
# Euclid distance= tensor([321.9282], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9996], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(453.7371, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[360.7429]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004c.json Query  1 len= 560
# predicted_span= tensor([[207.1623, 274.4272]], grad_fn=<AbsBackward0>) gold_span= tensor([37., 44.], requires_grad=True)
# Euclid distance= tensor([286.4471], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9986], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(400.5895, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[319.7472]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004c.json Query  2 len= 560
# predicted_span= tensor([[216.3625, 260.6946]], grad_fn=<AbsBackward0>) gold_span= tensor([64., 64.], requires_grad=True)
# Euclid distance= tensor([248.8034], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9957], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(349.0571, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[278.1641]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004c.json Query  3 len= 560
# predicted_span= tensor([[216.0181, 259.9452]], grad_fn=<AbsBackward0>) gold_span= tensor([ 66., 193.], requires_grad=True)
# Euclid distance= tensor([164.2775], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9345], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(216.9633, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[178.5183]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004c.json Query  4 len= 560
# predicted_span= tensor([[202.0429, 277.5122]], grad_fn=<AbsBackward0>) gold_span= tensor([208., 257.], requires_grad=True)
# Euclid distance= tensor([21.3597], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9987], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(26.4693, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[22.6002]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004c.json Query  5 len= 560
# predicted_span= tensor([[202.7877, 274.0003]], grad_fn=<AbsBackward0>) gold_span= tensor([260., 292.], requires_grad=True)
# Euclid distance= tensor([59.9770], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9959], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(75.2120, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[63.7592]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004c.json Query  6 len= 560
# predicted_span= tensor([[223.9222, 265.3809]], grad_fn=<AbsBackward0>) gold_span= tensor([294., 312.], requires_grad=True)
# Euclid distance= tensor([84.1679], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9985], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(116.6969, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[93.5582]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004c.json Query  7 len= 560
# predicted_span= tensor([[225.9214, 265.5073]], grad_fn=<AbsBackward0>) gold_span= tensor([327., 351.], requires_grad=True)
# Euclid distance= tensor([132.3854], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9990], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(186.5713, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[148.3401]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004c.json Query  8 len= 560
# predicted_span= tensor([[202.2000, 274.6293]], grad_fn=<AbsBackward0>) gold_span= tensor([ 62., 351.], requires_grad=True)
# Euclid distance= tensor([159.6513], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.8961], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(216.5707, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[175.6257]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004c.json Query  9 len= 560
# predicted_span= tensor([[216.6081, 259.2473]], grad_fn=<AbsBackward0>) gold_span= tensor([353., 430.], requires_grad=True)
# Euclid distance= tensor([218.5389], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([1.0000], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(307.1447, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[244.5437]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004c.json Query  10 len= 560
# predicted_span= tensor([[212.2758, 253.5577]], grad_fn=<AbsBackward0>) gold_span= tensor([432., 448.], requires_grad=True)
# Euclid distance= tensor([293.4050], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9975], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(414.1665, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[329.0304]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: Bmr006.json Query  0 len= 1295
# predicted_span= tensor([[333.3752, 381.0641]], grad_fn=<AbsBackward0>) gold_span= tensor([38., 64.], requires_grad=True)
# Euclid distance= tensor([433.3315], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9833], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(612.4393, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[486.2459]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bmr006.json Query  1 len= 1295
# predicted_span= tensor([[327.4962, 379.3489]], grad_fn=<AbsBackward0>) gold_span= tensor([ 65., 102.], requires_grad=True)
# Euclid distance= tensor([381.8725], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9895], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(539.8450, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[428.5565]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bmr006.json Query  2 len= 1295
# predicted_span= tensor([[331.8752, 374.0712]], grad_fn=<AbsBackward0>) gold_span= tensor([157., 162.], requires_grad=True)
# Euclid distance= tensor([274.8737], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9990], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(386.9464, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[307.8291]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bmr006.json Query  3 len= 1295
# predicted_span= tensor([[339.6353, 387.6352]], grad_fn=<AbsBackward0>) gold_span= tensor([162., 233.], requires_grad=True)
# Euclid distance= tensor([235.5129], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9937], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(332.2704, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[264.0392]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bmr006.json Query  4 len= 1295
# predicted_span= tensor([[341.6661, 392.1732]], grad_fn=<AbsBackward0>) gold_span= tensor([370., 412.], requires_grad=True)
# Euclid distance= tensor([34.5820], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9999], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(48.1607, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[38.5234]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bmr006.json Query  5 len= 1295
# predicted_span= tensor([[340.7841, 387.9791]], grad_fn=<AbsBackward0>) gold_span= tensor([421., 437.], requires_grad=True)
# Euclid distance= tensor([94.0087], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9989], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(129.2368, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[104.0695]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: TS3004a.json Query  0 len= 421
# predicted_span= tensor([[220.0432, 275.3378]], grad_fn=<AbsBackward0>) gold_span= tensor([201., 343.], requires_grad=True)
# Euclid distance= tensor([70.2910], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9896], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(86.7054, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[74.2400]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: TS3004a.json Query  1 len= 421
# predicted_span= tensor([[223.2252, 271.1357]], grad_fn=<AbsBackward0>) gold_span= tensor([201., 221.], requires_grad=True)
# Euclid distance= tensor([54.8411], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9988], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(72.3609, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[59.5701]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: TS3004a.json Query  2 len= 421
# predicted_span= tensor([[214.4722, 263.2250]], grad_fn=<AbsBackward0>) gold_span= tensor([274., 290.], requires_grad=True)
# Euclid distance= tensor([65.2722], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9973], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(86.3028, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[70.9661]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: TS3004a.json Query  3 len= 421
# predicted_span= tensor([[218.5547, 267.2743]], grad_fn=<AbsBackward0>) gold_span= tensor([304., 340.], requires_grad=True)
# Euclid distance= tensor([112.2049], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9990], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(158.1710, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[125.7434]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: TS3004a.json Query  4 len= 421
# predicted_span= tensor([[192.6889, 280.6743]], grad_fn=<AbsBackward0>) gold_span= tensor([344., 434.], requires_grad=True)
# Euclid distance= tensor([215.4154], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9976], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(304.6368, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[241.7931]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: TS3004a.json Query  5 len= 421
# predicted_span= tensor([[221.3536, 278.0103]], grad_fn=<AbsBackward0>) gold_span= tensor([344., 364.], requires_grad=True)
# Euclid distance= tensor([149.7878], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9964], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(208.6361, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[166.8726]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: IS1003a.json Query  0 len= 292
# predicted_span= tensor([[185.0080, 281.9429]], grad_fn=<AbsBackward0>) gold_span= tensor([4., 4.], requires_grad=True)
# Euclid distance= tensor([331.6869], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9791], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(458.9509, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[368.3323]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: IS1003a.json Query  1 len= 292
# predicted_span= tensor([[194.1598, 243.2315]], grad_fn=<AbsBackward0>) gold_span= tensor([28., 30.], requires_grad=True)
# Euclid distance= tensor([270.3271], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9970], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(379.3913, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[302.2820]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: IS1003a.json Query  2 len= 292
# predicted_span= tensor([[189.5157, 276.2747]], grad_fn=<AbsBackward0>) gold_span= tensor([19., 25.], requires_grad=True)
# Euclid distance= tensor([303.6685], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9988], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(421.7904, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[337.8436]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: IS1003a.json Query  3 len= 292
# predicted_span= tensor([[194.1808, 283.4694]], grad_fn=<AbsBackward0>) gold_span= tensor([ 35., 112.], requires_grad=True)
# Euclid distance= tensor([233.9664], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9560], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(330.6501, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[262.5279]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: IS1003a.json Query  4 len= 292
# predicted_span= tensor([[206.2419, 256.2845]], grad_fn=<AbsBackward0>) gold_span= tensor([ 89., 100.], requires_grad=True)
# Euclid distance= tensor([195.3727], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9988], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(273.5264, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[218.2039]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: IS1003a.json Query  5 len= 292
# predicted_span= tensor([[207.1260, 265.2147]], grad_fn=<AbsBackward0>) gold_span= tensor([ 71., 104.], requires_grad=True)
# Euclid distance= tensor([210.9987], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9980], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(297.3407, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[236.4196]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: education_13.json Query  0 len= 132
# predicted_span= tensor([[ 69.7268, 111.6979]], grad_fn=<AbsBackward0>) gold_span= tensor([ 1., 16.], requires_grad=True)
# Euclid distance= tensor([117.8197], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.8797], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(164.4248, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[131.3819]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_13.json Query  1 len= 132
# predicted_span= tensor([[ 94.3776, 104.0946]], grad_fn=<AbsBackward0>) gold_span= tensor([1., 5.], requires_grad=True)
# Euclid distance= tensor([136.1584], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.8582], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(192.4722, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[152.7990]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_13.json Query  2 len= 132
# predicted_span= tensor([[87.4905, 99.0527]], grad_fn=<AbsBackward0>) gold_span= tensor([12., 13.], requires_grad=True)
# Euclid distance= tensor([114.4722], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9998], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(161.5433, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[128.3540]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_13.json Query  3 len= 132
# predicted_span= tensor([[ 64.4964, 106.6388]], grad_fn=<AbsBackward0>) gold_span= tensor([17., 49.], requires_grad=True)
# Euclid distance= tensor([74.6870], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9780], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(105.1352, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[83.6400]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_13.json Query  4 len= 132
# predicted_span= tensor([[90.5484, 98.3049]], grad_fn=<AbsBackward0>) gold_span= tensor([17., 23.], requires_grad=True)
# Euclid distance= tensor([105.2625], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9942], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(148.8534, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[118.1491]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_13.json Query  5 len= 132
# predicted_span= tensor([[ 99.5426, 113.5721]], grad_fn=<AbsBackward0>) gold_span= tensor([42., 44.], requires_grad=True)
# Euclid distance= tensor([90.2852], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9991], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(127.1146, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[101.1169]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_13.json Query  6 len= 132
# predicted_span= tensor([[ 68.3943, 108.3983]], grad_fn=<AbsBackward0>) gold_span= tensor([ 95., 105.], requires_grad=True)
# Euclid distance= tensor([26.8218], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9851], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(30.0039, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[27.4093]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_13.json Query  7 len= 132
# predicted_span= tensor([[84.4731, 93.6752]], grad_fn=<AbsBackward0>) gold_span= tensor([95., 96.], requires_grad=True)
# Euclid distance= tensor([10.7805], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9989], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(12.8516, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[11.2432]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_13.json Query  8 len= 132
# predicted_span= tensor([[90.1161, 98.6676]], grad_fn=<AbsBackward0>) gold_span= tensor([ 97., 101.], requires_grad=True)
# Euclid distance= tensor([7.2683], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9997], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(9.2162, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[7.7615]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_13.json Query  9 len= 132
# predicted_span= tensor([[ 72.1642, 116.3509]], grad_fn=<AbsBackward0>) gold_span= tensor([106., 132.], requires_grad=True)
# Euclid distance= tensor([37.2794], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9926], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(49.4849, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[40.6030]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_13.json Query  10 len= 132
# predicted_span= tensor([[ 89.1303, 107.9928]], grad_fn=<AbsBackward0>) gold_span= tensor([111., 114.], requires_grad=True)
# Euclid distance= tensor([22.6797], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9966], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(27.8769, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[23.9212]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_13.json Query  11 len= 132
# predicted_span= tensor([[86.5622, 94.1845]], grad_fn=<AbsBackward0>) gold_span= tensor([128., 130.], requires_grad=True)
# Euclid distance= tensor([54.7708], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9994], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(77.2532, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[61.3971]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: covid_4.json Query  0 len= 275
# predicted_span= tensor([[ 81.3743, 112.1291]], grad_fn=<AbsBackward0>) gold_span= tensor([11., 38.], requires_grad=True)
# Euclid distance= tensor([102.2139], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9407], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(144.5034, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[114.7118]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_4.json Query  1 len= 275
# predicted_span= tensor([[113.2808, 115.9671]], grad_fn=<AbsBackward0>) gold_span= tensor([28., 38.], requires_grad=True)
# Euclid distance= tensor([115.5495], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9904], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(163.2480, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[129.6350]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_4.json Query  2 len= 275
# predicted_span= tensor([[100.8978, 103.1886]], grad_fn=<AbsBackward0>) gold_span= tensor([50., 64.], requires_grad=True)
# Euclid distance= tensor([64.2366], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9938], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(90.0865, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[71.8037]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_4.json Query  3 len= 275
# predicted_span= tensor([[ 84.6231, 114.3508]], grad_fn=<AbsBackward0>) gold_span= tensor([39., 49.], requires_grad=True)
# Euclid distance= tensor([79.7006], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9994], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(110.9739, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[88.7759]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_4.json Query  4 len= 275
# predicted_span= tensor([[97.6452, 99.8758]], grad_fn=<AbsBackward0>) gold_span= tensor([39., 49.], requires_grad=True)
# Euclid distance= tensor([77.6376], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9948], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(109.5209, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[87.0362]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_4.json Query  5 len= 275
# predicted_span= tensor([[108.6955, 118.0872]], grad_fn=<AbsBackward0>) gold_span= tensor([127., 134.], requires_grad=True)
# Euclid distance= tensor([24.2543], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9999], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(34.2173, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[27.1914]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_4.json Query  6 len= 275
# predicted_span= tensor([[ 84.3878, 111.3798]], grad_fn=<AbsBackward0>) gold_span= tensor([163., 175.], requires_grad=True)
# Euclid distance= tensor([101.1306], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9949], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(142.2324, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[113.2035]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_4.json Query  7 len= 275
# predicted_span= tensor([[110.5360, 112.5758]], grad_fn=<AbsBackward0>) gold_span= tensor([163., 175.], requires_grad=True)
# Euclid distance= tensor([81.5430], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9997], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(114.8882, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[91.3582]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_4.json Query  8 len= 275
# predicted_span= tensor([[108.8180, 118.3592]], grad_fn=<AbsBackward0>) gold_span= tensor([252., 254.], requires_grad=True)
# Euclid distance= tensor([197.2295], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9993], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(278.8228, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[221.3423]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_4.json Query  9 len= 275
# predicted_span= tensor([[ 82.6554, 109.2174]], grad_fn=<AbsBackward0>) gold_span= tensor([109., 122.], requires_grad=True)
# Euclid distance= tensor([29.2820], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9967], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(39.1272, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[31.9883]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_4.json Query  10 len= 275
# predicted_span= tensor([[116.5189, 122.6144]], grad_fn=<AbsBackward0>) gold_span= tensor([ 96., 122.], requires_grad=True)
# Euclid distance= tensor([20.5280], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9957], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(21.1332, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[20.5897]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_4.json Query  11 len= 275
# predicted_span= tensor([[100.2819, 102.9840]], grad_fn=<AbsBackward0>) gold_span= tensor([213., 214.], requires_grad=True)
# Euclid distance= tensor([158.2085], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9999], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(223.7342, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[177.5805]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: covid_9.json Query  0 len= 321
# predicted_span= tensor([[104.8540, 112.3536]], grad_fn=<AbsBackward0>) gold_span= tensor([17., 47.], requires_grad=True)
# Euclid distance= tensor([109.4962], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9196], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(153.2075, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[122.2566]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_9.json Query  1 len= 321
# predicted_span= tensor([[106.5932, 102.9557]], grad_fn=<AbsBackward0>) gold_span= tensor([37., 43.], requires_grad=True)
# Euclid distance= tensor([91.8581], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9958], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(129.5490, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[102.9654]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_9.json Query  2 len= 321
# predicted_span= tensor([[114.8557, 117.7689]], grad_fn=<AbsBackward0>) gold_span= tensor([22., 41.], requires_grad=True)
# Euclid distance= tensor([120.4809], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9609], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(169.6246, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[134.9339]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_9.json Query  3 len= 321
# predicted_span= tensor([[104.1881, 119.4828]], grad_fn=<AbsBackward0>) gold_span= tensor([49., 55.], requires_grad=True)
# Euclid distance= tensor([84.8749], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9999], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(119.6709, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[95.1261]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_9.json Query  4 len= 321
# predicted_span= tensor([[114.2323, 116.7689]], grad_fn=<AbsBackward0>) gold_span= tensor([69., 82.], requires_grad=True)
# Euclid distance= tensor([57.0512], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9972], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(80.0012, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[63.7685]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: covid_9.json Query  5 len= 321
# predicted_span= tensor([[ 95.6640, 127.8474]], grad_fn=<AbsBackward0>) gold_span= tensor([237., 253.], requires_grad=True)
# Euclid distance= tensor([188.7830], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9939], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(266.4886, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[211.7072]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: education_9.json Query  0 len= 194
# predicted_span= tensor([[ 95.6893, 110.7771]], grad_fn=<AbsBackward0>) gold_span= tensor([10., 10.], requires_grad=True)
# Euclid distance= tensor([132.2826], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9973], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(186.4664, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[148.2408]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_9.json Query  1 len= 194
# predicted_span= tensor([[101.8867, 118.8187]], grad_fn=<AbsBackward0>) gold_span= tensor([13., 18.], requires_grad=True)
# Euclid distance= tensor([134.4071], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9965], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(189.7054, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[150.7182]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_9.json Query  2 len= 194
# predicted_span= tensor([[105.6859, 123.5330]], grad_fn=<AbsBackward0>) gold_span= tensor([21., 23.], requires_grad=True)
# Euclid distance= tensor([131.4480], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9995], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(185.2189, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[147.2774]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_9.json Query  3 len= 194
# predicted_span= tensor([[ 99.4362, 116.3263]], grad_fn=<AbsBackward0>) gold_span= tensor([46., 49.], requires_grad=True)
# Euclid distance= tensor([85.9549], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9989], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(120.7624, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[96.1662]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_9.json Query  4 len= 194
# predicted_span= tensor([[100.4660, 110.9356]], grad_fn=<AbsBackward0>) gold_span= tensor([50., 55.], requires_grad=True)
# Euclid distance= tensor([75.3367], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([1.0000], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(106.4016, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[84.5068]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_9.json Query  5 len= 194
# predicted_span= tensor([[102.8603, 111.2795]], grad_fn=<AbsBackward0>) gold_span= tensor([64., 66.], requires_grad=True)
# Euclid distance= tensor([59.6688], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9997], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(84.1399, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[66.8790]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_9.json Query  6 len= 194
# predicted_span= tensor([[ 92.3833, 103.5325]], grad_fn=<AbsBackward0>) gold_span= tensor([90., 93.], requires_grad=True)
# Euclid distance= tensor([10.7988], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9992], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(12.9158, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[11.2754]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_9.json Query  7 len= 194
# predicted_span= tensor([[106.1018, 116.2871]], grad_fn=<AbsBackward0>) gold_span= tensor([94., 95.], requires_grad=True)
# Euclid distance= tensor([24.4866], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9992], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(33.3888, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[27.0022]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_9.json Query  8 len= 194
# predicted_span= tensor([[103.5429, 119.4801]], grad_fn=<AbsBackward0>) gold_span= tensor([ 97., 100.], requires_grad=True)
# Euclid distance= tensor([20.5496], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9984], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(26.0230, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[21.9324]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_9.json Query  9 len= 194
# predicted_span= tensor([[ 90.2714, 103.3383]], grad_fn=<AbsBackward0>) gold_span= tensor([151., 154.], requires_grad=True)
# Euclid distance= tensor([79.0859], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9983], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(111.3903, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[88.5911]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_9.json Query  10 len= 194
# predicted_span= tensor([[ 96.9647, 124.5920]], grad_fn=<AbsBackward0>) gold_span= tensor([157., 158.], requires_grad=True)
# Euclid distance= tensor([68.7047], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9927], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(93.4433, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[75.6718]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_9.json Query  11 len= 194
# predicted_span= tensor([[ 98.4228, 109.4174]], grad_fn=<AbsBackward0>) gold_span= tensor([159., 171.], requires_grad=True)
# Euclid distance= tensor([86.3829], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9999], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(122.1597, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[96.9599]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: education_4.json Query  0 len= 226
# predicted_span= tensor([[107.6589, 122.1241]], grad_fn=<AbsBackward0>) gold_span= tensor([20., 38.], requires_grad=True)
# Euclid distance= tensor([121.4947], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9718], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(171.7830, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[136.3587]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_4.json Query  1 len= 226
# predicted_span= tensor([[110.1182, 112.0352]], grad_fn=<AbsBackward0>) gold_span= tensor([31., 33.], requires_grad=True)
# Euclid distance= tensor([111.8314], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9997], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(158.1535, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[125.5265]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_4.json Query  2 len= 226
# predicted_span= tensor([[ 97.1372, 110.7186]], grad_fn=<AbsBackward0>) gold_span= tensor([31., 31.], requires_grad=True)
# Euclid distance= tensor([103.5818], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9979], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(145.8558, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[116.0168]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_4.json Query  3 len= 226
# predicted_span= tensor([[ 99.9688, 107.8079]], grad_fn=<AbsBackward0>) gold_span= tensor([39., 56.], requires_grad=True)
# Euclid distance= tensor([80.0078], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9903], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(112.7767, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[89.6586]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_4.json Query  4 len= 226
# predicted_span= tensor([[ 96.0851, 103.9734]], grad_fn=<AbsBackward0>) gold_span= tensor([44., 47.], requires_grad=True)
# Euclid distance= tensor([77.1935], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([1.0000], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(109.0585, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[86.6033]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_4.json Query  5 len= 226
# predicted_span= tensor([[ 93.8327, 100.5680]], grad_fn=<AbsBackward0>) gold_span= tensor([47., 47.], requires_grad=True)
# Euclid distance= tensor([71.1535], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9994], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(100.4006, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[79.7777]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_4.json Query  6 len= 226
# predicted_span= tensor([[101.6447, 115.9308]], grad_fn=<AbsBackward0>) gold_span= tensor([57., 94.], requires_grad=True)
# Euclid distance= tensor([49.7404], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9848], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(66.5754, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[54.3791]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_4.json Query  7 len= 226
# predicted_span= tensor([[ 99.1536, 105.9115]], grad_fn=<AbsBackward0>) gold_span= tensor([72., 81.], requires_grad=True)
# Euclid distance= tensor([36.8497], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9997], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(52.0650, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[41.3432]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_4.json Query  8 len= 226
# predicted_span= tensor([[ 84.3502, 123.0075]], grad_fn=<AbsBackward0>) gold_span= tensor([82., 89.], requires_grad=True)
# Euclid distance= tensor([34.0886], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9897], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(36.3577, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[34.4181]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_4.json Query  9 len= 226
# predicted_span= tensor([[101.0355, 113.2431]], grad_fn=<AbsBackward0>) gold_span= tensor([ 95., 157.], requires_grad=True)
# Euclid distance= tensor([44.1712], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9831], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(49.7924, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[45.2388]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_4.json Query  10 len= 226
# predicted_span= tensor([[101.2347, 108.3699]], grad_fn=<AbsBackward0>) gold_span= tensor([126., 131.], requires_grad=True)
# Euclid distance= tensor([33.5476], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9999], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(47.3954, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[37.6369]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_4.json Query  11 len= 226
# predicted_span= tensor([[ 85.4207, 114.2948]], grad_fn=<AbsBackward0>) gold_span= tensor([146., 157.], requires_grad=True)
# Euclid distance= tensor([74.1187], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9942], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(103.2845, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[82.5907]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: education_17.json Query  0 len= 125
# predicted_span= tensor([[84.9320, 98.2405]], grad_fn=<AbsBackward0>) gold_span= tensor([ 2., 12.], requires_grad=True)
# Euclid distance= tensor([119.6459], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.8537], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(169.1724, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[134.2851]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_17.json Query  1 len= 125
# predicted_span= tensor([[88.5118, 99.5040]], grad_fn=<AbsBackward0>) gold_span= tensor([ 9., 12.], requires_grad=True)
# Euclid distance= tensor([118.2331], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9965], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(167.0158, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[132.6364]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_17.json Query  2 len= 125
# predicted_span= tensor([[ 89.5836, 101.0740]], grad_fn=<AbsBackward0>) gold_span= tensor([14., 18.], requires_grad=True)
# Euclid distance= tensor([112.3129], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9979], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(158.6577, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[125.9968]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_17.json Query  3 len= 125
# predicted_span= tensor([[ 78.6967, 108.2812]], grad_fn=<AbsBackward0>) gold_span= tensor([27., 31.], requires_grad=True)
# Euclid distance= tensor([92.9782], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9961], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(128.9779, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[103.3769]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_17.json Query  4 len= 125
# predicted_span= tensor([[ 82.5772, 105.8299]], grad_fn=<AbsBackward0>) gold_span= tensor([31., 31.], requires_grad=True)
# Euclid distance= tensor([90.8830], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9925], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(126.4071, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[101.1781]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_17.json Query  5 len= 125
# predicted_span= tensor([[ 82.2185, 105.1021]], grad_fn=<AbsBackward0>) gold_span= tensor([28., 30.], requires_grad=True)
# Euclid distance= tensor([92.6281], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9962], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(129.3206, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[103.3110]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_17.json Query  6 len= 125
# predicted_span= tensor([[ 82.5853, 114.2493]], grad_fn=<AbsBackward0>) gold_span= tensor([47., 58.], requires_grad=True)
# Euclid distance= tensor([66.5604], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9985], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(91.8346, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[73.8118]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_17.json Query  7 len= 125
# predicted_span= tensor([[ 96.6515, 109.5857]], grad_fn=<AbsBackward0>) gold_span= tensor([52., 52.], requires_grad=True)
# Euclid distance= tensor([72.8688], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9980], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(102.2371, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[81.4704]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_17.json Query  8 len= 125
# predicted_span= tensor([[ 95.9007, 102.5768]], grad_fn=<AbsBackward0>) gold_span= tensor([54., 58.], requires_grad=True)
# Euclid distance= tensor([61.1781], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([1.0000], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(86.4775, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[68.6537]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_17.json Query  9 len= 125
# predicted_span= tensor([[ 77.6659, 105.3865]], grad_fn=<AbsBackward0>) gold_span= tensor([119., 125.], requires_grad=True)
# Euclid distance= tensor([45.7515], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9921], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(60.9477, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[49.9107]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: education_17.json Query  10 len= 125
# predicted_span= tensor([[76.3803, 84.9380]], grad_fn=<AbsBackward0>) gold_span= tensor([119., 120.], requires_grad=True)
# Euclid distance= tensor([55.1886], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9988], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(77.6817, grad_fn=<SumBackward0>)
# ...
# Euclid distance= tensor([149.9602], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9992], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(209.5991, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[167.3476]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: TS3011a.json Query  4 len= 307
# predicted_span= tensor([[202.3213, 249.4420]], grad_fn=<AbsBackward0>) gold_span= tensor([119., 136.], requires_grad=True)
# Euclid distance= tensor([140.7534], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9993], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(196.7632, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[157.0860]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: TS3011a.json Query  5 len= 307
# predicted_span= tensor([[200.4708, 253.1811]], grad_fn=<AbsBackward0>) gold_span= tensor([278., 297.], requires_grad=True)
# Euclid distance= tensor([89.0555], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9966], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(121.3481, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[98.1725]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: TS3011d.json Query  0 len= 663
# predicted_span= tensor([[233.9894, 316.7043]], grad_fn=<AbsBackward0>) gold_span= tensor([48., 76.], requires_grad=True)
# Euclid distance= tensor([304.1884], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9973], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(426.6937, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[340.0592]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: TS3011d.json Query  1 len= 663
# predicted_span= tensor([[250.2082, 308.4253]], grad_fn=<AbsBackward0>) gold_span= tensor([224., 243.], requires_grad=True)
# Euclid distance= tensor([70.4794], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9980], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(91.6335, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[76.0624]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: TS3011d.json Query  2 len= 663
# predicted_span= tensor([[246.0873, 306.8233]], grad_fn=<AbsBackward0>) gold_span= tensor([352., 388.], requires_grad=True)
# Euclid distance= tensor([133.4435], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9982], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(187.0894, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[149.1419]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: TS3011d.json Query  3 len= 663
# predicted_span= tensor([[252.2031, 304.2663]], grad_fn=<AbsBackward0>) gold_span= tensor([ 77., 152.], requires_grad=True)
# Euclid distance= tensor([232.1231], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9752], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(327.4694, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[260.2314]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: TS3011d.json Query  4 len= 663
# predicted_span= tensor([[257.8017, 309.3111]], grad_fn=<AbsBackward0>) gold_span= tensor([ 77., 152.], requires_grad=True)
# Euclid distance= tensor([239.6582], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9746], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(338.1128, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[268.6842]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: TS3011d.json Query  5 len= 663
# predicted_span= tensor([[250.0588, 299.7882]], grad_fn=<AbsBackward0>) gold_span= tensor([406., 421.], requires_grad=True)
# Euclid distance= tensor([197.5094], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9974], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(277.1530, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[220.8400]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: ES2004a.json Query  0 len= 303
# predicted_span= tensor([[200.7674, 254.8081]], grad_fn=<AbsBackward0>) gold_span= tensor([173., 311.], requires_grad=True)
# Euclid distance= tensor([62.6782], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9873], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(83.9593, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[68.5486]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004a.json Query  1 len= 303
# predicted_span= tensor([[189.4219, 240.9751]], grad_fn=<AbsBackward0>) gold_span= tensor([203., 232.], requires_grad=True)
# Euclid distance= tensor([16.2763], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9986], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(22.5532, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[18.0869]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004a.json Query  2 len= 303
# predicted_span= tensor([[196.4660, 245.3968]], grad_fn=<AbsBackward0>) gold_span= tensor([233., 246.], requires_grad=True)
# Euclid distance= tensor([36.5389], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9965], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(37.1372, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[36.5856]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004a.json Query  3 len= 303
# predicted_span= tensor([[183.3141, 224.0007]], grad_fn=<AbsBackward0>) gold_span= tensor([282., 315.], requires_grad=True)
# Euclid distance= tensor([134.2377], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9990], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(189.6851, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[150.6150]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004a.json Query  4 len= 303
# predicted_span= tensor([[176.9593, 252.3324]], grad_fn=<AbsBackward0>) gold_span= tensor([131., 171.], requires_grad=True)
# Euclid distance= tensor([93.4196], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9991], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(127.2918, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[102.9823]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004a.json Query  5 len= 303
# predicted_span= tensor([[197.2477, 244.5281]], grad_fn=<AbsBackward0>) gold_span= tensor([173., 183.], requires_grad=True)
# Euclid distance= tensor([66.1337], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9969], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(85.7758, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[71.2979]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: ES2011a.json Query  0 len= 269
# predicted_span= tensor([[205.9619, 266.3799]], grad_fn=<AbsBackward0>) gold_span= tensor([10., 97.], requires_grad=True)
# Euclid distance= tensor([259.0186], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.8497], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(365.3419, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[290.3558]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2011a.json Query  1 len= 269
# predicted_span= tensor([[199.0249, 251.6761]], grad_fn=<AbsBackward0>) gold_span= tensor([ 98., 138.], requires_grad=True)
# Euclid distance= tensor([152.0799], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9987], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(214.7010, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[170.5562]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2011a.json Query  2 len= 269
# predicted_span= tensor([[173.3108, 258.5699]], grad_fn=<AbsBackward0>) gold_span= tensor([139., 169.], requires_grad=True)
# Euclid distance= tensor([95.9166], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9952], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(123.8807, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[103.2195]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2011a.json Query  3 len= 269
# predicted_span= tensor([[201.6153, 253.7865]], grad_fn=<AbsBackward0>) gold_span= tensor([173., 215.], requires_grad=True)
# Euclid distance= tensor([48.1999], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([1.0000], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(67.4018, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[53.8014]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2011a.json Query  4 len= 269
# predicted_span= tensor([[198.1570, 245.7567]], grad_fn=<AbsBackward0>) gold_span= tensor([219., 236.], requires_grad=True)
# Euclid distance= tensor([23.0135], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9976], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(30.5997, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[25.0843]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2011a.json Query  5 len= 269
# predicted_span= tensor([[199.2014, 251.7034]], grad_fn=<AbsBackward0>) gold_span= tensor([84., 96.], requires_grad=True)
# Euclid distance= tensor([193.6877], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9988], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(270.9048, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[216.2189]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: ES2004d.json Query  0 len= 726
# predicted_span= tensor([[249.4859, 303.3816]], grad_fn=<AbsBackward0>) gold_span= tensor([126., 321.], requires_grad=True)
# Euclid distance= tensor([124.7365], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9511], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(141.1043, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[127.8836]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004d.json Query  1 len= 726
# predicted_span= tensor([[244.5529, 287.6017]], grad_fn=<AbsBackward0>) gold_span= tensor([217., 237.], requires_grad=True)
# Euclid distance= tensor([57.6168], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9993], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(78.1546, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[63.3803]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004d.json Query  2 len= 726
# predicted_span= tensor([[237.2270, 291.9790]], grad_fn=<AbsBackward0>) gold_span= tensor([246., 276.], requires_grad=True)
# Euclid distance= tensor([18.2289], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9990], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(24.7520, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[20.0620]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004d.json Query  3 len= 726
# predicted_span= tensor([[235.7014, 313.0324]], grad_fn=<AbsBackward0>) gold_span= tensor([335., 534.], requires_grad=True)
# Euclid distance= tensor([242.2538], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9964], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(320.2662, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[263.3713]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004d.json Query  4 len= 726
# predicted_span= tensor([[250.0444, 302.9785]], grad_fn=<AbsBackward0>) gold_span= tensor([420., 441.], requires_grad=True)
# Euclid distance= tensor([218.9403], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9975], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(307.9771, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[245.0987]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: ES2004d.json Query  5 len= 726
# predicted_span= tensor([[244.5924, 297.8908]], grad_fn=<AbsBackward0>) gold_span= tensor([463., 508.], requires_grad=True)
# Euclid distance= tensor([303.0640], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9987], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(428.5168, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[340.1460]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: Bro019.json Query  0 len= 748
# predicted_span= tensor([[274.3282, 361.6291]], grad_fn=<AbsBackward0>) gold_span= tensor([ 9., 18.], requires_grad=True)
# Euclid distance= tensor([434.1429], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9829], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(608.9573, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[485.3276]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bro019.json Query  1 len= 748
# predicted_span= tensor([[299.5891, 365.2163]], grad_fn=<AbsBackward0>) gold_span= tensor([46., 90.], requires_grad=True)
# Euclid distance= tensor([374.2345], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9771], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(528.8054, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[419.8887]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bro019.json Query  2 len= 748
# predicted_span= tensor([[301.4463, 363.7894]], grad_fn=<AbsBackward0>) gold_span= tensor([53., 75.], requires_grad=True)
# Euclid distance= tensor([380.9525], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9971], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(537.2356, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[427.0054]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bro019.json Query  3 len= 748
# predicted_span= tensor([[276.6841, 373.4178]], grad_fn=<AbsBackward0>) gold_span= tensor([358., 448.], requires_grad=True)
# Euclid distance= tensor([110.3394], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9993], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(155.8982, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[123.7942]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bro019.json Query  4 len= 748
# predicted_span= tensor([[295.7994, 357.3313]], grad_fn=<AbsBackward0>) gold_span= tensor([447., 463.], requires_grad=True)
# Euclid distance= tensor([184.4655], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9971], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(256.8693, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[205.4789]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bro019.json Query  5 len= 748
# predicted_span= tensor([[300.1179, 365.7831]], grad_fn=<AbsBackward0>) gold_span= tensor([406., 416.], requires_grad=True)
# Euclid distance= tensor([117.1869], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9963], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(156.0991, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[127.8361]], grad_fn=<NormBackward1>)
#
# ==============================
# Meeting  meeting: Bmr023.json Query  0 len= 704
# predicted_span= tensor([[281.7030, 355.3470]], grad_fn=<AbsBackward0>) gold_span= tensor([32., 35.], requires_grad=True)
# Euclid distance= tensor([406.1696], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9975], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(570.0499, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[454.1862]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bmr023.json Query  1 len= 704
# predicted_span= tensor([[278.6658, 352.4720]], grad_fn=<AbsBackward0>) gold_span= tensor([32., 47.], requires_grad=True)
# Euclid distance= tensor([392.6285], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9975], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(552.1378, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[439.4749]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bmr023.json Query  2 len= 704
# predicted_span= tensor([[284.6326, 345.9058]], grad_fn=<AbsBackward0>) gold_span= tensor([229., 323.], requires_grad=True)
# Euclid distance= tensor([60.1636], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9974], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(78.5384, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[65.0437]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bmr023.json Query  3 len= 704
# predicted_span= tensor([[278.6289, 342.5613]], grad_fn=<AbsBackward0>) gold_span= tensor([101., 108.], requires_grad=True)
# Euclid distance= tensor([294.2296], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9976], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(412.1902, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[328.7160]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bmr023.json Query  4 len= 704
# predicted_span= tensor([[270.4178, 330.6367]], grad_fn=<AbsBackward0>) gold_span= tensor([101., 114.], requires_grad=True)
# Euclid distance= tensor([275.0161], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9992], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(386.0545, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[307.5577]], grad_fn=<NormBackward1>)
#
# Meeting  meeting: Bmr023.json Query  5 len= 704
# predicted_span= tensor([[278.6289, 342.5613]], grad_fn=<AbsBackward0>) gold_span= tensor([133., 140.], requires_grad=True)
# Euclid distance= tensor([249.4772], grad_fn=<SqrtBackward0>)
# cos_sim= tensor([0.9970], grad_fn=<SumBackward1>)
# Manhattan dis= tensor(348.1902, grad_fn=<SumBackward0>)
# Minkowski dis= tensor([[278.2060]], grad_fn=<NormBackward1>)
#
# ==============================
# Average Euclid Distance for prediction = tensor([195.5410], grad_fn=<DivBackward0>)
# Average cosine similarity for prediction = tensor([0.9854], grad_fn=<DivBackward0>)
# Average Manhattan distance for prediction = tensor(271.2793, grad_fn=<DivBackward0>)
# Average Minkowski distance for prediction = tensor([278.2060], grad_fn=<DivBackward0>)
